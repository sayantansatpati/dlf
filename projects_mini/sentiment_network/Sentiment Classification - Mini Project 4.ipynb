# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (40% Off: **traskud17**)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem"
#
#
# - Curate a Dataset
# - Developing a "Predictive Theory"
# - **PROJECT 1**: Quick Theory Validation
#
#
# - Transforming Text to Numbers
# - **PROJECT 2**: Creating the Input/Output Data
#
#
# - Putting it all together in a Neural Network
# - **PROJECT 3**: Building our Neural Network
#
#
# - Understanding Neural Noise
# - **PROJECT 4**: Making Learning Faster by Reducing Noise
#
#
# - Analyzing Inefficiencies in our Network
# - **PROJECT 5**: Making our Network Train and Run Faster
#
#
# - Further Noise Reduction
# - **PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary
#
#
# - Analysis: What's going on in the weights?

# %% [markdown]
# # Lesson: Curate a Dataset

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation

# %%
from collections import Counter
import numpy as np

# %%
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %%
for i in range(len(reviews)):
    if(labels[i] == 'POSITIVE'):
        for word in reviews[i].split(" "):
            positive_counts[word] += 1
            total_counts[word] += 1
    else:
        for word in reviews[i].split(" "):
            negative_counts[word] += 1
            total_counts[word] += 1

# %%
positive_counts.most_common()
# Out:
# [('', 550468),
#  ('the', 173324),
#  ('.', 159654),
#  ('and', 89722),
#  ('a', 83688),
#  ('of', 76855),
#  ('to', 66746),
#  ('is', 57245),
#  ('in', 50215),
#  ('br', 49235),
#  ('it', 48025),
#  ('i', 40743),
#  ('that', 35630),
#  ('this', 35080),
#  ('s', 33815),
#  ('as', 26308),
#  ('with', 23247),
#  ('for', 22416),
#  ('was', 21917),
#  ('film', 20937),
#  ('but', 20822),
#  ('movie', 19074),
#  ('his', 17227),
#  ('on', 17008),
#  ('you', 16681),
#  ('he', 16282),
#  ('are', 14807),
#  ('not', 14272),
#  ('t', 13720),
#  ('one', 13655),
#  ('have', 12587),
#  ('be', 12416),
#  ('by', 11997),
#  ('all', 11942),
#  ('who', 11464),
#  ('an', 11294),
#  ('at', 11234),
#  ('from', 10767),
#  ('her', 10474),
#  ('they', 9895),
#  ('has', 9186),
#  ('so', 9154),
#  ('like', 9038),
#  ('about', 8313),
#  ('very', 8305),
#  ('out', 8134),
#  ('there', 8057),
#  ('she', 7779),
#  ('what', 7737),
#  ('or', 7732),
#  ('good', 7720),
#  ('more', 7521),
#  ('when', 7456),
#  ('some', 7441),
#  ('if', 7285),
#  ('just', 7152),
#  ('can', 7001),
#  ('story', 6780),
#  ('time', 6515),
#  ('my', 6488),
#  ('great', 6419),
#  ('well', 6405),
#  ('up', 6321),
#  ('which', 6267),
#  ('their', 6107),
#  ('see', 6026),
#  ('also', 5550),
#  ('we', 5531),
#  ('really', 5476),
#  ('would', 5400),
#  ('will', 5218),
#  ('me', 5167),
#  ('had', 5148),
#  ('only', 5137),
#  ('him', 5018),
#  ('even', 4964),
#  ('most', 4864),
#  ('other', 4858),
#  ('were', 4782),
#  ('first', 4755),
#  ('than', 4736),
#  ('much', 4685),
#  ('its', 4622),
#  ('no', 4574),
#  ('into', 4544),
#  ('people', 4479),
#  ('best', 4319),
#  ('love', 4301),
#  ('get', 4272),
#  ('how', 4213),
#  ('life', 4199),
#  ('been', 4189),
#  ('because', 4079),
#  ('way', 4036),
#  ('do', 3941),
#  ('made', 3823),
#  ('films', 3813),
#  ('them', 3805),
#  ('after', 3800),
#  ('many', 3766),
#  ('two', 3733),
#  ('too', 3659),
#  ('think', 3655),
#  ('movies', 3586),
#  ('characters', 3560),
#  ('character', 3514),
#  ('don', 3468),
#  ('man', 3460),
#  ('show', 3432),
#  ('watch', 3424),
#  ('seen', 3414),
#  ('then', 3358),
#  ('little', 3341),
#  ('still', 3340),
#  ('make', 3303),
#  ('could', 3237),
#  ('never', 3226),
#  ('being', 3217),
#  ('where', 3173),
#  ('does', 3069),
#  ('over', 3017),
#  ('any', 3002),
#  ('while', 2899),
#  ('know', 2833),
#  ('did', 2790),
#  ('years', 2758),
#  ('here', 2740),
#  ('ever', 2734),
#  ('end', 2696),
#  ('these', 2694),
#  ('such', 2590),
#  ('real', 2568),
#  ('scene', 2567),
#  ('back', 2547),
#  ('those', 2485),
#  ('though', 2475),
#  ('off', 2463),
#  ('new', 2458),
#  ('your', 2453),
#  ('go', 2440),
#  ('acting', 2437),
#  ('plot', 2432),
#  ('world', 2429),
#  ('scenes', 2427),
#  ('say', 2414),
#  ('through', 2409),
#  ('makes', 2390),
#  ('better', 2381),
#  ('now', 2368),
#  ('work', 2346),
#  ('young', 2343),
#  ('old', 2311),
#  ('ve', 2307),
#  ('find', 2272),
#  ('both', 2248),
#  ('before', 2177),
#  ('us', 2162),
#  ('again', 2158),
#  ('series', 2153),
#  ('quite', 2143),
#  ('something', 2135),
#  ('cast', 2133),
#  ('should', 2121),
#  ('part', 2098),
#  ('always', 2088),
#  ('lot', 2087),
#  ('another', 2075),
#  ('actors', 2047),
#  ('director', 2040),
#  ('family', 2032),
#  ('between', 2016),
#  ('own', 2016),
#  ('m', 1998),
#  ('may', 1997),
#  ('same', 1972),
#  ('role', 1967),
#  ('watching', 1966),
#  ('every', 1954),
#  ('funny', 1953),
#  ('doesn', 1935),
#  ('performance', 1928),
#  ('few', 1918),
#  ('bad', 1907),
#  ('look', 1900),
#  ('re', 1884),
#  ('why', 1855),
#  ('things', 1849),
#  ('times', 1832),
#  ('big', 1815),
#  ('however', 1795),
#  ('actually', 1790),
#  ('action', 1789),
#  ('going', 1783),
#  ('bit', 1757),
#  ('comedy', 1742),
#  ('down', 1740),
#  ('music', 1738),
#  ('must', 1728),
#  ('take', 1709),
#  ('saw', 1692),
#  ('long', 1690),
#  ('right', 1688),
#  ('fun', 1686),
#  ('fact', 1684),
#  ('excellent', 1683),
#  ('around', 1674),
#  ('didn', 1672),
#  ('without', 1671),
#  ('thing', 1662),
#  ('thought', 1639),
#  ('got', 1635),
#  ('each', 1630),
#  ('day', 1614),
#  ('feel', 1597),
#  ('seems', 1596),
#  ('come', 1594),
#  ('done', 1586),
#  ('beautiful', 1580),
#  ('especially', 1572),
#  ('played', 1571),
#  ('almost', 1566),
#  ('want', 1562),
#  ('yet', 1556),
#  ('give', 1553),
#  ('pretty', 1549),
#  ('last', 1543),
#  ('since', 1519),
#  ('different', 1504),
#  ('although', 1501),
#  ('gets', 1490),
#  ('true', 1487),
#  ('interesting', 1481),
#  ('job', 1470),
#  ('enough', 1455),
#  ('our', 1454),
#  ('shows', 1447),
#  ('horror', 1441),
#  ('woman', 1439),
#  ('tv', 1400),
#  ('probably', 1398),
#  ('father', 1395),
#  ('original', 1393),
#  ('girl', 1390),
#  ('point', 1379),
#  ('plays', 1378),
#  ('wonderful', 1372),
#  ('far', 1358),
#  ('course', 1358),
#  ('john', 1350),
#  ('rather', 1340),
#  ('isn', 1328),
#  ('ll', 1326),
#  ('dvd', 1324),
#  ('later', 1324),
#  ('whole', 1310),
#  ('war', 1310),
#  ('d', 1307),
#  ('found', 1306),
#  ('away', 1306),
#  ('screen', 1305),
#  ('nothing', 1300),
#  ('year', 1297),
#  ('once', 1296),
#  ('hard', 1294),
#  ('together', 1280),
#  ('set', 1277),
#  ('am', 1277),
#  ('having', 1266),
#  ('making', 1265),
#  ('place', 1263),
#  ('might', 1260),
#  ('comes', 1260),
#  ('sure', 1253),
#  ('american', 1248),
#  ('play', 1245),
#  ('kind', 1244),
#  ('takes', 1242),
#  ('perfect', 1242),
#  ('performances', 1237),
#  ('himself', 1230),
#  ('worth', 1221),
#  ('everyone', 1221),
#  ('anyone', 1214),
#  ('actor', 1203),
#  ('three', 1201),
#  ('wife', 1196),
#  ('classic', 1192),
#  ('goes', 1186),
#  ('ending', 1178),
#  ('version', 1168),
#  ('star', 1149),
#  ('enjoy', 1146),
#  ('book', 1142),
#  ('nice', 1132),
#  ('everything', 1128),
#  ('during', 1124),
#  ('put', 1118),
#  ('seeing', 1111),
#  ('least', 1102),
#  ('house', 1100),
#  ('high', 1095),
#  ('watched', 1094),
#  ('men', 1087),
#  ('loved', 1087),
#  ('night', 1082),
#  ('anything', 1075),
#  ('guy', 1071),
#  ('believe', 1071),
#  ('top', 1063),
#  ('amazing', 1058),
#  ('hollywood', 1056),
#  ('looking', 1053),
#  ('main', 1044),
#  ('definitely', 1043),
#  ('gives', 1031),
#  ('home', 1029),
#  ('seem', 1028),
#  ('episode', 1023),
#  ('sense', 1020),
#  ('audience', 1020),
#  ('truly', 1017),
#  ('special', 1011),
#  ('second', 1009),
#  ('fan', 1009),
#  ('short', 1009),
#  ('mind', 1005),
#  ('human', 1001),
#  ('recommend', 999),
#  ('full', 996),
#  ('black', 995),
#  ('help', 991),
#  ('along', 989),
#  ('trying', 987),
#  ('small', 986),
#  ('death', 985),
#  ('friends', 981),
#  ('remember', 974),
#  ('often', 970),
#  ('said', 966),
#  ('favorite', 962),
#  ('heart', 959),
#  ('early', 957),
#  ('left', 956),
#  ('until', 955),
#  ('script', 954),
#  ('let', 954),
#  ('maybe', 937),
#  ('today', 936),
#  ('less', 934),
#  ('live', 934),
#  ('moments', 933),
#  ('others', 929),
#  ('brilliant', 926),
#  ('shot', 925),
#  ('liked', 923),
#  ('become', 916),
#  ('won', 915),
#  ('used', 910),
#  ('style', 907),
#  ('mother', 895),
#  ('lives', 894),
#  ('came', 893),
#  ('stars', 890),
#  ('cinema', 889),
#  ('looks', 885),
#  ('perhaps', 884),
#  ('read', 882),
#  ('enjoyed', 879),
#  ('boy', 875),
#  ('drama', 873),
#  ('highly', 871),
#  ('given', 870),
#  ('playing', 867),
#  ('use', 864),
#  ('next', 859),
#  ('women', 858),
#  ('fine', 857),
#  ('effects', 856),
#  ('kids', 854),
#  ('entertaining', 853),
#  ('need', 852),
#  ('line', 850),
#  ('works', 848),
#  ('someone', 847),
#  ('mr', 836),
#  ('simply', 835),
#  ('picture', 833),
#  ('children', 833),
#  ('keep', 831),
#  ('friend', 831),
#  ('face', 831),
#  ('dark', 830),
#  ('certainly', 828),
#  ('overall', 828),
#  ('minutes', 827),
#  ('wasn', 824),
#  ('history', 822),
#  ('finally', 820),
#  ('couple', 816),
#  ('against', 815),
#  ('son', 809),
#  ('understand', 808),
#  ('lost', 807),
#  ('michael', 805),
#  ('else', 801),
#  ('throughout', 798),
#  ('fans', 797),
#  ('city', 792),
#  ('reason', 789),
#  ('written', 787),
#  ('production', 787),
#  ('several', 784),
#  ('school', 783),
#  ('based', 781),
#  ('rest', 781),
#  ('try', 780),
#  ('dead', 776),
#  ('hope', 775),
#  ('strong', 768),
#  ('white', 765),
#  ('tell', 759),
#  ('itself', 758),
#  ('half', 753),
#  ('person', 749),
#  ('sometimes', 746),
#  ('start', 744),
#  ('past', 744),
#  ('genre', 743),
#  ('beginning', 739),
#  ('final', 739),
#  ('town', 738),
#  ('art', 734),
#  ('humor', 732),
#  ('game', 732),
#  ('yes', 731),
#  ('idea', 731),
#  ('late', 730),
#  ('becomes', 729),
#  ('despite', 729),
#  ('case', 726),
#  ('able', 726),
#  ('money', 723),
#  ('completely', 721),
#  ('child', 721),
#  ('side', 719),
#  ('camera', 716),
#  ('getting', 714),
#  ('instead', 712),
#  ('soon', 702),
#  ('under', 700),
#  ('viewer', 699),
#  ('age', 697),
#  ('stories', 696),
#  ('days', 696),
#  ('felt', 694),
#  ('simple', 694),
#  ('roles', 693),
#  ('video', 688),
#  ('either', 683),
#  ('name', 683),
#  ('doing', 677),
#  ('turns', 674),
#  ('wants', 671),
#  ('close', 671),
#  ('title', 669),
#  ('wrong', 668),
#  ('went', 666),
#  ('james', 665),
#  ('evil', 659),
#  ('episodes', 657),
#  ('budget', 657),
#  ('relationship', 655),
#  ('fantastic', 653),
#  ('piece', 653),
#  ('david', 651),
#  ('turn', 648),
#  ('murder', 646),
#  ('parts', 645),
#  ('brother', 644),
#  ('absolutely', 643),
#  ('head', 643),
#  ('experience', 642),
#  ('eyes', 641),
#  ('sex', 638),
#  ('direction', 637),
#  ('called', 637),
#  ('directed', 636),
#  ('lines', 634),
#  ('behind', 633),
#  ('sort', 632),
#  ('actress', 631),
#  ('lead', 630),
#  ('oscar', 628),
#  ('example', 627),
#  ('including', 627),
#  ('musical', 625),
#  ('known', 625),
#  ('chance', 621),
#  ('score', 620),
#  ('hit', 619),
#  ('feeling', 619),
#  ('already', 619),
#  ('voice', 615),
#  ('living', 612),
#  ('moment', 612),
#  ('low', 610),
#  ('supporting', 610),
#  ('ago', 609),
#  ('themselves', 608),
#  ('hilarious', 605),
#  ('reality', 605),
#  ('jack', 604),
#  ('told', 603),
#  ('hand', 601),
#  ('moving', 600),
#  ('dialogue', 600),
#  ('quality', 600),
#  ('happy', 599),
#  ('song', 599),
#  ('matter', 598),
#  ('paul', 598),
#  ('light', 594),
#  ('future', 593),
#  ('entire', 592),
#  ('finds', 591),
#  ('gave', 589),
#  ('laugh', 587),
#  ('released', 586),
#  ('expect', 584),
#  ('fight', 581),
#  ('particularly', 580),
#  ('cinematography', 579),
#  ('police', 579),
#  ('sound', 578),
#  ('type', 578),
#  ('whose', 578),
#  ('enjoyable', 573),
#  ('view', 573),
#  ('number', 572),
#  ('daughter', 572),
#  ('husband', 572),
#  ('romantic', 572),
#  ('documentary', 571),
#  ('self', 570),
#  ('superb', 569),
#  ('took', 569),
#  ('modern', 569),
#  ('robert', 569),
#  ('mean', 566),
#  ('shown', 563),
#  ('coming', 561),
#  ('important', 560),
#  ('king', 559),
#  ('leave', 559),
#  ('change', 558),
#  ('wanted', 555),
#  ('somewhat', 555),
#  ('tells', 554),
#  ('country', 552),
#  ('events', 552),
#  ('run', 552),
#  ('career', 552),
#  ('heard', 550),
#  ('season', 550),
#  ('greatest', 549),
#  ('girls', 549),
#  ('etc', 547),
#  ('care', 546),
#  ('starts', 545),
#  ('english', 542),
#  ('killer', 541),
#  ('guys', 540),
#  ('animation', 540),
#  ('totally', 540),
#  ('tale', 540),
#  ('usual', 539),
#  ('opinion', 535),
#  ('miss', 535),
#  ('easy', 531),
#  ('violence', 531),
#  ('songs', 530),
#  ('british', 528),
#  ('says', 526),
#  ('realistic', 525),
#  ('writing', 524),
#  ('act', 522),
#  ('writer', 522),
#  ('comic', 521),
#  ('thriller', 519),
#  ('television', 517),
#  ('power', 516),
#  ('ones', 515),
#  ('kid', 514),
#  ('novel', 513),
#  ('york', 513),
#  ('alone', 512),
#  ('problem', 512),
#  ('attention', 509),
#  ('involved', 508),
#  ('kill', 507),
#  ('extremely', 507),
#  ('seemed', 506),
#  ('hero', 505),
#  ('french', 505),
#  ('rock', 504),
#  ('stuff', 501),
#  ('wish', 499),
#  ('begins', 498),
#  ('taken', 497),
#  ('sad', 497),
#  ('ways', 496),
#  ('richard', 495),
#  ('knows', 494),
#  ('atmosphere', 493),
#  ('surprised', 491),
#  ('similar', 491),
#  ('car', 491),
#  ('taking', 491),
#  ('perfectly', 490),
#  ('george', 490),
#  ('team', 489),
#  ('eye', 489),
#  ('sequence', 489),
#  ('across', 489),
#  ('due', 488),
#  ('powerful', 488),
#  ('serious', 488),
#  ('room', 488),
#  ('among', 488),
#  ('b', 487),
#  ('strange', 487),
#  ('order', 487),
#  ('cannot', 487),
#  ('beauty', 486),
#  ('famous', 485),
#  ('herself', 484),
#  ('tries', 484),
#  ('happened', 484),
#  ('myself', 484),
#  ('class', 483),
#  ('four', 482),
#  ('cool', 481),
#  ('theme', 479),
#  ('anyway', 479),
#  ('release', 479),
#  ('opening', 478),
#  ('entertainment', 477),
#  ('unique', 475),
#  ('exactly', 475),
#  ('slow', 475),
#  ('ends', 475),
#  ('easily', 474),
#  ('level', 474),
#  ('red', 474),
#  ('o', 474),
#  ('interest', 472),
#  ('happen', 471),
#  ('crime', 470),
#  ('viewing', 468),
#  ('memorable', 467),
#  ('sets', 467),
#  ('stop', 466),
#  ('group', 466),
#  ('problems', 463),
#  ('dance', 463),
#  ('sister', 463),
#  ('working', 463),
#  ('message', 463),
#  ('knew', 462),
#  ('nature', 461),
#  ('mystery', 461),
#  ('bring', 460),
#  ('brought', 459),
#  ('believable', 459),
#  ('thinking', 459),
#  ('mostly', 458),
#  ('couldn', 457),
#  ('disney', 457),
#  ('society', 456),
#  ('lady', 455),
#  ('within', 455),
#  ('blood', 454),
#  ('parents', 453),
#  ('viewers', 453),
#  ('upon', 453),
#  ('tom', 452),
#  ('peter', 452),
#  ('meets', 452),
#  ('soundtrack', 452),
#  ('form', 452),
#  ('usually', 452),
#  ('local', 450),
#  ('follow', 448),
#  ('certain', 448),
#  ('whether', 447),
#  ('possible', 446),
#  ('emotional', 445),
#  ('above', 444),
#  ('de', 444),
#  ('killed', 444),
#  ('god', 443),
#  ('middle', 443),
#  ('flick', 442),
#  ('needs', 442),
#  ('happens', 442),
#  ('masterpiece', 441),
#  ('period', 440),
#  ('major', 440),
#  ('named', 439),
#  ('haven', 439),
#  ('particular', 438),
#  ('th', 438),
#  ('earth', 437),
#  ('feature', 437),
#  ('stand', 436),
#  ('typical', 435),
#  ('words', 435),
#  ('elements', 433),
#  ('obviously', 433),
#  ('romance', 431),
#  ('jane', 430),
#  ('yourself', 427),
#  ('showing', 427),
#  ('fantasy', 426),
#  ('brings', 426),
#  ('america', 423),
#  ('guess', 423),
#  ('huge', 422),
#  ('unfortunately', 422),
#  ('running', 421),
#  ('indeed', 421),
#  ('talent', 420),
#  ('stage', 419),
#  ('started', 418),
#  ('leads', 417),
#  ('sweet', 417),
#  ('japanese', 417),
#  ('poor', 416),
#  ('deal', 416),
#  ('incredible', 413),
#  ('personal', 413),
#  ('fast', 412),
#  ('became', 410),
#  ('deep', 410),
#  ('hours', 409),
#  ('giving', 408),
#  ('nearly', 408),
#  ('dream', 408),
#  ('turned', 407),
#  ('clearly', 407),
#  ('near', 406),
#  ('obvious', 406),
#  ('cut', 405),
#  ('surprise', 405),
#  ('era', 404),
#  ('body', 404),
#  ('female', 403),
#  ('hour', 403),
#  ('five', 403),
#  ('note', 399),
#  ('truth', 398),
#  ('learn', 398),
#  ('feels', 397),
#  ('except', 397),
#  ('tony', 397),
#  ('match', 397),
#  ('complete', 394),
#  ('filmed', 394),
#  ('clear', 394),
#  ('lots', 393),
#  ('street', 393),
#  ('older', 393),
#  ('eventually', 393),
#  ('keeps', 393),
#  ('buy', 392),
#  ('stewart', 391),
#  ('william', 391),
#  ('joe', 390),
#  ('meet', 390),
#  ('fall', 390),
#  ('unlike', 389),
#  ('rating', 389),
#  ('talking', 389),
#  ('difficult', 389),
#  ('shots', 389),
#  ('dramatic', 388),
#  ('means', 388),
#  ('present', 386),
#  ('subject', 386),
#  ('situation', 386),
#  ('wonder', 386),
#  ('appears', 386),
#  ('comments', 385),
#  ('lee', 383),
#  ('general', 383),
#  ('sequences', 383),
#  ('points', 382),
#  ('earlier', 382),
#  ('check', 379),
#  ('gone', 379),
#  ('suspense', 378),
#  ('ten', 378),
#  ('recommended', 378),
#  ('third', 377),
#  ('business', 377),
#  ('talk', 375),
#  ('beyond', 375),
#  ('leaves', 375),
#  ('portrayal', 374),
#  ('beautifully', 373),
#  ('bill', 372),
#  ('single', 372),
#  ('plenty', 371),
#  ('word', 371),
#  ('falls', 370),
#  ('whom', 370),
#  ('battle', 369),
#  ('scary', 369),
#  ('non', 369),
#  ('figure', 369),
#  ('return', 368),
#  ('using', 368),
#  ('add', 367),
#  ('doubt', 367),
#  ('success', 366),
#  ('hear', 366),
#  ('solid', 366),
#  ('touching', 365),
#  ('oh', 365),
#  ('jokes', 365),
#  ('political', 365),
#  ('awesome', 364),
#  ('boys', 364),
#  ('hell', 364),
#  ('recently', 362),
#  ('sexual', 362),
#  ('dog', 362),
#  ('straight', 361),
#  ('features', 361),
#  ('please', 361),
#  ('wouldn', 361),
#  ('lack', 360),
#  ('setting', 360),
#  ('forget', 360),
#  ('married', 359),
#  ('mark', 359),
#  ('social', 357),
#  ('interested', 356),
#  ('adventure', 356),
#  ('terrific', 355),
#  ('actual', 355),
#  ('brothers', 355),
#  ('sees', 355),
#  ('move', 354),
#  ('call', 354),
#  ('various', 353),
#  ('dr', 353),
#  ('theater', 353),
#  ('animated', 352),
#  ('western', 351),
#  ('baby', 350),
#  ('space', 350),
#  ('disappointed', 348),
#  ('leading', 348),
#  ('portrayed', 346),
#  ('aren', 346),
#  ('smith', 345),
#  ('screenplay', 345),
#  ('towards', 344),
#  ('hate', 344),
#  ('noir', 343),
#  ('kelly', 342),
#  ('outstanding', 342),
#  ('decent', 342),
#  ('directors', 341),
#  ('journey', 341),
#  ('looked', 340),
#  ('none', 340),
#  ('effective', 340),
#  ('caught', 339),
#  ('fi', 339),
#  ('cold', 339),
#  ('storyline', 339),
#  ('mary', 339),
#  ('sci', 339),
#  ('charming', 338),
#  ('rich', 338),
#  ('manages', 337),
#  ('popular', 337),
#  ('harry', 337),
#  ('rare', 337),
#  ('spirit', 336),
#  ('appreciate', 335),
#  ('open', 335),
#  ('acted', 334),
#  ('basically', 334),
#  ('moves', 334),
#  ('pace', 333),
#  ('mention', 333),
#  ('century', 333),
#  ('inside', 333),
#  ('subtle', 333),
#  ('deserves', 333),
#  ('boring', 333),
#  ('familiar', 332),
#  ('background', 332),
#  ('ben', 331),
#  ('creepy', 330),
#  ('supposed', 330),
#  ('secret', 329),
#  ('die', 328),
#  ('jim', 328),
#  ('question', 327),
#  ('natural', 327),
#  ('effect', 327),
#  ('rate', 326),
#  ('language', 326),
#  ('impressive', 326),
#  ('intelligent', 325),
#  ('saying', 325),
#  ('realize', 324),
#  ('scott', 324),
#  ('material', 324),
#  ('telling', 324),
#  ('singing', 323),
#  ('dancing', 322),
#  ('imagine', 321),
#  ('adult', 321),
#  ('visual', 321),
#  ('office', 320),
#  ('kept', 320),
#  ('uses', 319),
#  ('pure', 318),
#  ('wait', 318),
#  ('stunning', 318),
#  ('seriously', 317),
#  ('review', 317),
#  ('copy', 317),
#  ('previous', 317),
#  ('create', 316),
#  ('created', 316),
#  ('hot', 316),
#  ('magic', 316),
#  ('reading', 316),
#  ('somehow', 316),
#  ('stay', 315),
#  ('crazy', 315),
#  ('attempt', 315),
#  ('escape', 315),
#  ('frank', 315),
#  ('air', 315),
#  ('hands', 314),
#  ('filled', 313),
#  ('expected', 312),
#  ('average', 312),
#  ('surprisingly', 312),
#  ('complex', 311),
#  ('studio', 310),
#  ('quickly', 310),
#  ('successful', 310),
#  ('plus', 309),
#  ('male', 309),
#  ('co', 307),
#  ('exciting', 306),
#  ('casting', 306),
#  ('following', 306),
#  ('images', 306),
#  ('minute', 306),
#  ('german', 305),
#  ('follows', 305),
#  ('themes', 305),
#  ('reasons', 305),
#  ('members', 305),
#  ('e', 305),
#  ('cute', 304),
#  ('genius', 304),
#  ('touch', 304),
#  ('edge', 304),
#  ('free', 304),
#  ('outside', 303),
#  ('reviews', 302),
#  ('ok', 302),
#  ('younger', 302),
#  ('admit', 302),
#  ('odd', 301),
#  ('master', 301),
#  ('fighting', 301),
#  ('break', 300),
#  ('comment', 300),
#  ('thanks', 300),
#  ('recent', 300),
#  ('apart', 299),
#  ('begin', 298),
#  ('lovely', 298),
#  ('emotions', 298),
#  ('doctor', 297),
#  ('italian', 297),
#  ('party', 297),
#  ('missed', 296),
#  ('sequel', 296),
#  ...]

# %%
pos_neg_ratios = Counter()

for term,cnt in list(total_counts.most_common()):
    if(cnt > 100):
        pos_neg_ratio = positive_counts[term] / float(negative_counts[term]+1)
        pos_neg_ratios[term] = pos_neg_ratio

for word,ratio in pos_neg_ratios.most_common():
    if(ratio > 1):
        pos_neg_ratios[word] = np.log(ratio)
    else:
        pos_neg_ratios[word] = -np.log((1 / (ratio+0.01)))

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 4.6913478822291435),
#  ('paulie', 4.0775374439057197),
#  ('felix', 3.1527360223636558),
#  ('polanski', 2.8233610476132043),
#  ('matthau', 2.8067217286092401),
#  ('victoria', 2.6810215287142909),
#  ('mildred', 2.6026896854443837),
#  ('gandhi', 2.5389738710582761),
#  ('flawless', 2.451005098112319),
#  ('superbly', 2.2600254785752498),
#  ('perfection', 2.1594842493533721),
#  ('astaire', 2.1400661634962708),
#  ('captures', 2.0386195471595809),
#  ('voight', 2.0301704926730531),
#  ('wonderfully', 2.0218960560332353),
#  ('powell', 1.9783454248084671),
#  ('brosnan', 1.9547990964725592),
#  ('lily', 1.9203768470501485),
#  ('bakshi', 1.9029851043382795),
#  ('lincoln', 1.9014583864844796),
#  ('refreshing', 1.8551812956655511),
#  ('breathtaking', 1.8481124057791867),
#  ('bourne', 1.8478489358790986),
#  ('lemmon', 1.8458266904983307),
#  ('delightful', 1.8002701588959635),
#  ('flynn', 1.7996646487351682),
#  ('andrews', 1.7764919970972666),
#  ('homer', 1.7692866133759964),
#  ('beautifully', 1.7626953362841438),
#  ('soccer', 1.7578579175523736),
#  ('elvira', 1.7397031072720019),
#  ('underrated', 1.7197859696029656),
#  ('gripping', 1.7165360479904674),
#  ('superb', 1.7091514458966952),
#  ('delight', 1.6714733033535532),
#  ('welles', 1.6677068205580761),
#  ('sadness', 1.663505133704376),
#  ('sinatra', 1.6389967146756448),
#  ('touching', 1.637217476541176),
#  ('timeless', 1.62924053973028),
#  ('macy', 1.6211339521972916),
#  ('unforgettable', 1.6177367152487956),
#  ('favorites', 1.6158688027643908),
#  ('stewart', 1.6119987332957739),
#  ('hartley', 1.6094379124341003),
#  ('sullivan', 1.6094379124341003),
#  ('extraordinary', 1.6094379124341003),
#  ('brilliantly', 1.5950491749820008),
#  ('friendship', 1.5677652160335325),
#  ('wonderful', 1.5645425925262093),
#  ('palma', 1.5553706911638245),
#  ('magnificent', 1.54663701119507),
#  ('finest', 1.5462590108125689),
#  ('jackie', 1.5439233053234738),
#  ('ritter', 1.5404450409471491),
#  ('tremendous', 1.5184661342283736),
#  ('freedom', 1.5091151908062312),
#  ('fantastic', 1.5048433868558566),
#  ('terrific', 1.5026699370083942),
#  ('sidney', 1.493925025312256),
#  ('noir', 1.493925025312256),
#  ('outstanding', 1.4910053152089213),
#  ('pleasantly', 1.4894785973551214),
#  ('mann', 1.4894785973551214),
#  ('nancy', 1.488077055429833),
#  ('marie', 1.4825711915553104),
#  ('marvelous', 1.4739999415389962),
#  ('excellent', 1.4647538505723599),
#  ('ruth', 1.4596256342054401),
#  ('stanwyck', 1.4412101187160054),
#  ('widmark', 1.4350845252893227),
#  ('splendid', 1.4271163556401458),
#  ('chan', 1.423108334242607),
#  ('exceptional', 1.4201959127955721),
#  ('tender', 1.410986973710262),
#  ('gentle', 1.4078005663408544),
#  ('poignant', 1.4022947024663317),
#  ('gem', 1.3932148039644643),
#  ('amazing', 1.3919815802404802),
#  ('davies', 1.3862943611198906),
#  ('fisher', 1.3862943611198906),
#  ('chilling', 1.3862943611198906),
#  ('captivating', 1.3862943611198906),
#  ('darker', 1.3652409519220583),
#  ('april', 1.3499267169490159),
#  ('kelly', 1.3461743673304654),
#  ('blake', 1.3418425985490567),
#  ('overlooked', 1.329135947279942),
#  ('ralph', 1.32818673031261),
#  ('bette', 1.3156767939059373),
#  ('hoffman', 1.3150668518315229),
#  ('cole', 1.3121863889661687),
#  ('shines', 1.3049487216659381),
#  ('powerful', 1.2999662776313934),
#  ('notch', 1.2950456896547455),
#  ('remarkable', 1.2883688239495823),
#  ('pitt', 1.286210902562908),
#  ('winters', 1.2833463918674481),
#  ('vivid', 1.2762934659055623),
#  ('gritty', 1.2757524867200667),
#  ('giallo', 1.2745029551317739),
#  ('portrait', 1.2704625455947689),
#  ('innocence', 1.2694300209805796),
#  ('psychiatrist', 1.2685113254635072),
#  ('favorite', 1.2668956297860055),
#  ('ensemble', 1.2656663733312759),
#  ('stunning', 1.2622417124499117),
#  ('burns', 1.259880436264232),
#  ('garbo', 1.258954938743289),
#  ('barbara', 1.2580400255962119),
#  ('panic', 1.2527629684953681),
#  ('holly', 1.2527629684953681),
#  ('philip', 1.2527629684953681),
#  ('carol', 1.2481440226390734),
#  ('perfect', 1.246742480713785),
#  ('appreciated', 1.2462482874741743),
#  ('favourite', 1.2411123512753928),
#  ('journey', 1.2367626271489269),
#  ('rural', 1.235471471385307),
#  ('bond', 1.2321436812926323),
#  ('builds', 1.2305398317106577),
#  ('brilliant', 1.2287554137664785),
#  ('brooklyn', 1.2286654169163074),
#  ('von', 1.225175011976539),
#  ('unfolds', 1.2163953243244932),
#  ('recommended', 1.2163953243244932),
#  ('daniel', 1.20215296760895),
#  ('perfectly', 1.1971931173405572),
#  ('crafted', 1.1962507582320256),
#  ('prince', 1.1939224684724346),
#  ('troubled', 1.192138346678933),
#  ('consequences', 1.1865810616140668),
#  ('haunting', 1.1814999484738773),
#  ('cinderella', 1.180052620608284),
#  ('alexander', 1.1759989522835299),
#  ('emotions', 1.1753049094563641),
#  ('boxing', 1.1735135968412274),
#  ('subtle', 1.1734135017508081),
#  ('curtis', 1.1649873576129823),
#  ('rare', 1.1566438362402944),
#  ('loved', 1.1563661500586044),
#  ('daughters', 1.1526795099383853),
#  ('courage', 1.1438688802562305),
#  ('dentist', 1.1426722784621401),
#  ('highly', 1.1420208631618658),
#  ('nominated', 1.1409146683587992),
#  ('tony', 1.1397491942285991),
#  ('draws', 1.1325138403437911),
#  ('everyday', 1.1306150197542835),
#  ('contrast', 1.1284652518177909),
#  ('cried', 1.1213405397456659),
#  ('fabulous', 1.1210851445201684),
#  ('fay', 1.120591195386885),
#  ('ned', 1.120591195386885),
#  ('emma', 1.1184149159642893),
#  ('sensitive', 1.113318436057805),
#  ('smooth', 1.1089750757036563),
#  ('dramas', 1.1080910326226534),
#  ('today', 1.1050431789984001),
#  ('helps', 1.1023091505494358),
#  ('inspiring', 1.0986122886681098),
#  ('jimmy', 1.0937696641923216),
#  ('awesome', 1.0931328229034842),
#  ('unique', 1.0881409888008142),
#  ('tragic', 1.0871835928444868),
#  ('intense', 1.0870514662670339),
#  ('stellar', 1.0857088838322018),
#  ('rival', 1.0822184788924332),
#  ('provides', 1.0797081340289569),
#  ('depression', 1.0782034170369026),
#  ('shy', 1.0775588794702773),
#  ('carrie', 1.076139432816051),
#  ('blend', 1.0753554265038423),
#  ('hank', 1.0736109864626924),
#  ('adorable', 1.0726368022648489),
#  ('diana', 1.0726368022648489),
#  ('unexpected', 1.0722255334949147),
#  ('achievement', 1.0668635903535293),
#  ('bettie', 1.0663514264498881),
#  ('happiness', 1.0632729222228008),
#  ('glorious', 1.0608719606852626),
#  ('davis', 1.0541605260972757),
#  ('terrifying', 1.0525211814678428),
#  ('beauty', 1.050410186850232),
#  ('ideal', 1.0479685558493548),
#  ('fears', 1.0467872208035236),
#  ('hong', 1.0438040521731147),
#  ('seasons', 1.0433496099930604),
#  ('fascinating', 1.0414538748281612),
#  ('carries', 1.0345904299031787),
#  ('satisfying', 1.0321225473992768),
#  ('definite', 1.0319209141694374),
#  ('touched', 1.0296194171811581),
#  ('greatest', 1.0248947127715422),
#  ('creates', 1.0241097613701886),
#  ('aunt', 1.023388867430522),
#  ('walter', 1.022328983918479),
#  ('spectacular', 1.0198314108149955),
#  ('portrayal', 1.0189810189761024),
#  ('ann', 1.0127808528183286),
#  ('enterprise', 1.0116009116784799),
#  ('musicals', 1.0096648026516135),
#  ('deeply', 1.0094845087721023),
#  ('incredible', 1.0061677561461084),
#  ('mature', 1.0060195018402847),
#  ('triumph', 0.99682959435816731),
#  ('margaret', 0.99682959435816731),
#  ('navy', 0.99493385919326827),
#  ('harry', 0.99176919305006062),
#  ('lucas', 0.990398704027877),
#  ('sweet', 0.98966110487955483),
#  ('joey', 0.98794672078059009),
#  ('oscar', 0.98721905111049713),
#  ('balance', 0.98649499054740353),
#  ('warm', 0.98485340331145166),
#  ('ages', 0.98449898190068863),
#  ('glover', 0.98082925301172619),
#  ('guilt', 0.98082925301172619),
#  ('carrey', 0.98082925301172619),
#  ('learns', 0.97881108885548895),
#  ('unusual', 0.97788374278196932),
#  ('sons', 0.97777581552483595),
#  ('complex', 0.97761897738147796),
#  ('essence', 0.97753435711487369),
#  ('brazil', 0.9769153536905899),
#  ('widow', 0.97650959186720987),
#  ('solid', 0.97537964824416146),
#  ('beautiful', 0.97326301262841053),
#  ('holmes', 0.97246100334120955),
#  ('awe', 0.97186058302896583),
#  ('vhs', 0.97116734209998934),
#  ('eerie', 0.97116734209998934),
#  ('lonely', 0.96873720724669754),
#  ('grim', 0.96873720724669754),
#  ('sport', 0.96825047080486615),
#  ('debut', 0.96508089604358704),
#  ('destiny', 0.96343751029985703),
#  ('thrillers', 0.96281074750904794),
#  ('tears', 0.95977584381389391),
#  ('rose', 0.95664202739772253),
#  ('ginger', 0.95551144502743635),
#  ('feelings', 0.95551144502743635),
#  ('winning', 0.95471810900804055),
#  ('stanley', 0.95387344302319799),
#  ('cox', 0.95343027882361187),
#  ('paris', 0.95278479030472663),
#  ('heart', 0.95238806924516806),
#  ('hooked', 0.95155887071161305),
#  ('comfortable', 0.94803943018873538),
#  ('mgm', 0.94446160884085151),
#  ('masterpiece', 0.94155039863339296),
#  ('themes', 0.94118828349588235),
#  ('danny', 0.93967118051821874),
#  ('anime', 0.93378388932167222),
#  ('perry', 0.93328830824272613),
#  ('joy', 0.93301752567946861),
#  ('lovable', 0.93081883243706487),
#  ('hal', 0.92953595862417571),
#  ('mysteries', 0.92953595862417571),
#  ('louis', 0.92871325187271225),
#  ('charming', 0.92520609553210742),
#  ('urban', 0.92367083917177761),
#  ('allows', 0.92183091224977043),
#  ('impact', 0.91815814604895041),
#  ('gradually', 0.91629073187415511),
#  ('italy', 0.91629073187415511),
#  ('lifestyle', 0.91629073187415511),
#  ('spy', 0.91289514287301687),
#  ('treat', 0.91193342650519937),
#  ('subsequent', 0.91056005716517008),
#  ('kennedy', 0.90981821736853763),
#  ('loving', 0.90967549275543591),
#  ('surprising', 0.90937028902958128),
#  ('quiet', 0.90648673177753425),
#  ('winter', 0.90624039602065365),
#  ('reveals', 0.90490540964902977),
#  ('raw', 0.90445627422715225),
#  ('funniest', 0.90078654533818991),
#  ('pleased', 0.89994159387262562),
#  ('norman', 0.89994159387262562),
#  ('thief', 0.89874642222324552),
#  ('season', 0.89827222637147675),
#  ('secrets', 0.89794159320595857),
#  ('colorful', 0.89705936994626756),
#  ('highest', 0.8967461358011849),
#  ('compelling', 0.89462923509297576),
#  ('danes', 0.89248008318043659),
#  ('castle', 0.88967708335606499),
#  ('kudos', 0.88889175768604067),
#  ('great', 0.88810470901464589),
#  ('bleak', 0.88730319500090271),
#  ('baseball', 0.88730319500090271),
#  ('subtitles', 0.88730319500090271),
#  ('winner', 0.88643776872447388),
#  ('tragedy', 0.88563699078315261),
#  ('todd', 0.88551907320740142),
#  ('nicely', 0.87924946019380601),
#  ('arthur', 0.87546873735389985),
#  ('essential', 0.87373111745535925),
#  ('gorgeous', 0.8731725250935497),
#  ('fonda', 0.87294029100054127),
#  ('eastwood', 0.87139541196626402),
#  ('focuses', 0.87082835779739776),
#  ('enjoyed', 0.87070195951624607),
#  ('natural', 0.86997924506912838),
#  ('intensity', 0.86835126958503595),
#  ('witty', 0.86824103423244681),
#  ('rob', 0.8642954367557748),
#  ('worlds', 0.86377269759070874),
#  ('health', 0.86113891179907498),
#  ('magical', 0.85953791528170564),
#  ('deeper', 0.85802182375017932),
#  ('lucy', 0.85618680780444956),
#  ('moving', 0.85566611005772031),
#  ('lovely', 0.85290640004681306),
#  ('purple', 0.8513711857748395),
#  ('memorable', 0.84801189112086062),
#  ('sings', 0.84729786038720367),
#  ('craig', 0.84342938360928321),
#  ('modesty', 0.84342938360928321),
#  ('relate', 0.84326559685926517),
#  ('episodes', 0.84223712084137292),
#  ('strong', 0.84167135777060931),
#  ('smith', 0.83959811108590054),
#  ('tear', 0.83704136022001441),
#  ('apartment', 0.83333115290549531),
#  ('princess', 0.83290912293510388),
#  ('disagree', 0.83290912293510388),
#  ('kung', 0.83173334384609199),
#  ('adventure', 0.83150561393278388),
#  ('columbo', 0.82667857318446791),
#  ('jake', 0.82667857318446791),
#  ('adds', 0.82485652591452319),
#  ('hart', 0.82472353834866463),
#  ('strength', 0.82417544296634937),
#  ('realizes', 0.82360006895738058),
#  ('dave', 0.8232003088081431),
#  ('childhood', 0.82208086393583857),
#  ('forbidden', 0.81989888619908913),
#  ('tight', 0.81883539572344199),
#  ('surreal', 0.8178506590609026),
#  ('manager', 0.81770990320170756),
#  ('dancer', 0.81574950265227764),
#  ('con', 0.81093021621632877),
#  ('studios', 0.81093021621632877),
#  ('miike', 0.80821651034473263),
#  ('realistic', 0.80807714723392232),
#  ('explicit', 0.80792269515237358),
#  ('kurt', 0.8060875917405409),
#  ('deals', 0.80535917116687328),
#  ('traditional', 0.80535917116687328),
#  ('holds', 0.80493858654806194),
#  ('carl', 0.80437281567016972),
#  ('touches', 0.80396154690023547),
#  ('gene', 0.80314807577427383),
#  ('albert', 0.8027669055771679),
#  ('abc', 0.80234647252493729),
#  ('cry', 0.80011930011211307),
#  ('sides', 0.7995275841185171),
#  ('eyre', 0.79850769621777162),
#  ('develops', 0.79850769621777162),
#  ('dances', 0.79694397424158891),
#  ('oscars', 0.79633141679517616),
#  ('legendary', 0.79600456599965308),
#  ('hearted', 0.79492987486988764),
#  ('importance', 0.79492987486988764),
#  ('portraying', 0.79356592830699269),
#  ('impressed', 0.79258107754813223),
#  ('waters', 0.79112758892014912),
#  ('empire', 0.79078565012386137),
#  ('edge', 0.789774016249017),
#  ('jean', 0.78845736036427028),
#  ('environment', 0.78845736036427028),
#  ('sentimental', 0.7864791203521645),
#  ('captured', 0.78623760362595729),
#  ('daring', 0.78592891401091158),
#  ('styles', 0.78592891401091158),
#  ('tense', 0.78275933924963248),
#  ('frank', 0.78275933924963248),
#  ('matches', 0.78275933924963248),
#  ('backgrounds', 0.78275933924963248),
#  ('gothic', 0.78209466657644144),
#  ('sharp', 0.7814397877056235),
#  ('achieved', 0.78015855754957497),
#  ('court', 0.77947526404844247),
#  ('steals', 0.7789140023173704),
#  ('rules', 0.77844476107184035),
#  ('colors', 0.77684619943659217),
#  ('reunion', 0.77318988823348167),
#  ('covers', 0.77139937745969345),
#  ('tale', 0.77010822169607374),
#  ('rain', 0.7683706017975328),
#  ('denzel', 0.76804848873306297),
#  ('stays', 0.76787072675588186),
#  ('blob', 0.76725515271366718),
#  ('maria', 0.76214005204689672),
#  ('conventional', 0.76214005204689672),
#  ('fresh', 0.76158434211317383),
#  ('midnight', 0.76096977689870637),
#  ('landscape', 0.75852993982279704),
#  ('animated', 0.75768570169751648),
#  ('titanic', 0.75666058628227129),
#  ('sunday', 0.75666058628227129),
#  ('spring', 0.7537718023763802),
#  ('cagney', 0.7537718023763802),
#  ('enjoyable', 0.75246375771636476),
#  ('immensely', 0.75198768058287868),
#  ('sir', 0.7507762933965817),
#  ('nevertheless', 0.75067102469813185),
#  ('driven', 0.74994477895307854),
#  ('performances', 0.74883252516063137),
#  ('nowadays', 0.74721440183022114),
#  ('memories', 0.74721440183022114),
#  ('simple', 0.74641420974143258),
#  ('leslie', 0.74533293373051557),
#  ('golden', 0.74533293373051557),
#  ('lovers', 0.74497224842453125),
#  ('relationship', 0.74484232345601786),
#  ('supporting', 0.74357803418683721),
#  ('che', 0.74262723782331497),
#  ('packed', 0.7410032017375805),
#  ('trek', 0.74021469141793106),
#  ('provoking', 0.73840377214806618),
#  ('strikes', 0.73759894313077912),
#  ('depiction', 0.73682224406260699),
#  ('emotional', 0.73678211645681524),
#  ('secretary', 0.7366322924996842),
#  ('influenced', 0.73511137965897755),
#  ('florida', 0.73511137965897755),
#  ('germany', 0.73288750920945944),
#  ('brings', 0.73142936713096229),
#  ('lewis', 0.73129894652432159),
#  ('elderly', 0.73088750854279239),
#  ('owner', 0.72743625403857748),
#  ('streets', 0.72666987259858895),
#  ('henry', 0.72642196944481741),
#  ('portrays', 0.72593700338293632),
#  ('bears', 0.7252354951114458),
#  ('china', 0.72489587887452556),
#  ('anger', 0.72439972406404984),
#  ('society', 0.72433010799663333),
#  ('available', 0.72415741730250549),
#  ('best', 0.72347034060446314),
#  ('bugs', 0.72270598280148979),
#  ('magic', 0.71878961117328299),
#  ('delivers', 0.71846498854423513),
#  ('verhoeven', 0.71846498854423513),
#  ('jim', 0.71783979315031676),
#  ('donald', 0.71667767797013937),
#  ('endearing', 0.71465338578090898),
#  ('relationships', 0.71393795022901896),
#  ('greatly', 0.71256526641704687),
#  ('brad', 0.71024161391924534),
#  ('charlie', 0.71024161391924534),
#  ('simon', 0.70967648251115578),
#  ('effectively', 0.70914752190638641),
#  ('march', 0.70774597998109789),
#  ('atmosphere', 0.70744773070214162),
#  ('influence', 0.70733181555190172),
#  ('genius', 0.706392407309966),
#  ('emotionally', 0.70556970055850243),
#  ('ken', 0.70526854109229009),
#  ('identity', 0.70484322032313651),
#  ('sophisticated', 0.70470800296102132),
#  ('dan', 0.70457587638356811),
#  ('andrew', 0.70329955202396321),
#  ('india', 0.70144598337464037),
#  ('roy', 0.69970458110610434),
#  ('surprisingly', 0.6995780708902356),
#  ('sky', 0.69780919366575667),
#  ('romantic', 0.69664981111114743),
#  ('match', 0.69566924999265523),
#  ('stylish', 0.69314718055994529),
#  ('meets', 0.69314718055994529),
#  ('britain', 0.69314718055994529),
#  ('cowboy', 0.69314718055994529),
#  ('beatty', 0.69314718055994529),
#  ('patient', 0.69314718055994529),
#  ('wave', 0.69314718055994529),
#  ('bitter', 0.69314718055994529),
#  ('affected', 0.69314718055994529),
#  ('love', 0.69198533541937324),
#  ('paul', 0.68980827929443067),
#  ('andy', 0.68846333124751902),
#  ('performance', 0.68797386327972465),
#  ('patrick', 0.68645819240914863),
#  ('unlike', 0.68546468438792907),
#  ('brooks', 0.68433655087779044),
#  ('refuses', 0.68348526964820844),
#  ('complaint', 0.6824518914431974),
#  ('award', 0.6824518914431974),
#  ('ride', 0.68229716453587952),
#  ('dawson', 0.68171848473632257),
#  ('luke', 0.68158635815886937),
#  ('wells', 0.68087708796813096),
#  ('france', 0.6804081547825156),
#  ('handsome', 0.68007509899259255),
#  ('sports', 0.68007509899259255),
#  ('directs', 0.67875844310784572),
#  ('rebel', 0.67875844310784572),
#  ('greater', 0.67605274720064523),
#  ('dreams', 0.67599410133369586),
#  ('effective', 0.67565402311242806),
#  ('interpretation', 0.67479804189174875),
#  ('works', 0.67445504754779284),
#  ('brando', 0.67445504754779284),
#  ('noble', 0.6737290947028437),
#  ('paced', 0.67314651385327573),
#  ('le', 0.67067432470788668),
#  ('master', 0.67015766233524654),
#  ('h', 0.6696166831497512),
#  ('rings', 0.66904962898088483),
#  ('easy', 0.66895995494594152),
#  ('city', 0.66820823221269321),
#  ('sunshine', 0.66782937257565544),
#  ('succeeds', 0.66647893347778397),
#  ('relations', 0.664159643686693),
#  ('england', 0.66387679825983203),
#  ('glimpse', 0.66329421741026418),
#  ('aired', 0.66268797307523675),
#  ('sees', 0.66263163663399482),
#  ('both', 0.66248336767382998),
#  ('definitely', 0.66199789483898808),
#  ('imaginative', 0.66139848224536502),
#  ('appreciate', 0.66083893732728749),
#  ('tricks', 0.66071190480679143),
#  ('striking', 0.66071190480679143),
#  ('carefully', 0.65999497324304479),
#  ('complicated', 0.65981076029235353),
#  ('perspective', 0.65962448852130173),
#  ('trilogy', 0.65877953705573755),
#  ('future', 0.65834665141052828),
#  ('lion', 0.65742909795786608),
#  ('victor', 0.65540685257709819),
#  ('douglas', 0.65540685257709819),
#  ('inspired', 0.65459851044271034),
#  ('marriage', 0.65392646740666405),
#  ('demands', 0.65392646740666405),
#  ('father', 0.65172321672194655),
#  ('page', 0.65123628494430852),
#  ('instant', 0.65058756614114943),
#  ('era', 0.6495567444850836),
#  ('saga', 0.64934455790155243),
#  ('ruthless', 0.64934455790155243),
#  ('joan', 0.64891392558311978),
#  ('joseph', 0.64841128671855386),
#  ('workers', 0.64829661439459352),
#  ('fantasy', 0.64726757480925168),
#  ('accomplished', 0.64551913157069074),
#  ('distant', 0.64551913157069074),
#  ('manhattan', 0.64435701639051324),
#  ('personal', 0.64355023942057321),
#  ('pushing', 0.64313675998528386),
#  ('individual', 0.64313675998528386),
#  ('meeting', 0.64313675998528386),
#  ('pleasant', 0.64250344774119039),
#  ('brave', 0.64185388617239469),
#  ('william', 0.64083139119578469),
#  ('hudson', 0.64077919504262937),
#  ('friendly', 0.63949446706762514),
#  ('eccentric', 0.63907995928966954),
#  ('awards', 0.63875310849414646),
#  ('jack', 0.63838309514997038),
#  ('seeking', 0.63808740337691783),
#  ('colonel', 0.63757732940513456),
#  ('divorce', 0.63757732940513456),
#  ('jane', 0.63443957973316734),
#  ('keeping', 0.63414883979798953),
#  ('gives', 0.63383568159497883),
#  ('ted', 0.63342794585832296),
#  ('animation', 0.63208692379869902),
#  ('progress', 0.6317782341836532),
#  ('concert', 0.63127177684185776),
#  ('larger', 0.63127177684185776),
#  ('nation', 0.6296337748376194),
#  ('albeit', 0.62739580299716491),
#  ('adapted', 0.62613647027698516),
#  ('discovers', 0.62542900650499444),
#  ('classic', 0.62504956428050518),
#  ('segment', 0.62335141862440335),
#  ('morgan', 0.62303761437291871),
#  ('mouse', 0.62294292188669675),
#  ('impressive', 0.62211140744319349),
#  ('ultimate', 0.62168821657780038),
#  ('artist', 0.62168821657780038),
#  ('griffith', 0.62117368093485603),
#  ('drew', 0.62082651898031915),
#  ('emily', 0.62082651898031915),
#  ('moved', 0.6197197120051281),
#  ('families', 0.61903920840622351),
#  ('profound', 0.61903920840622351),
#  ('innocent', 0.61851219917136446),
#  ('versions', 0.61730910416844087),
#  ('eddie', 0.61691981517206107),
#  ('criticism', 0.61651395453902935),
#  ('nature', 0.61594514653194088),
#  ('recognized', 0.61518563909023349),
#  ('sexuality', 0.61467556511845012),
#  ('contract', 0.61400986000122149),
#  ('brian', 0.61344043794920278),
#  ('remembered', 0.6131044728864089),
#  ('determined', 0.6123858239154869),
#  ('offers', 0.61207935747116349),
#  ('pleasure', 0.61195702582993206),
#  ('washington', 0.61180154110599294),
#  ('images', 0.61159731359583758),
#  ('games', 0.61067095873570676),
#  ('academy', 0.60872983874736208),
#  ('fashioned', 0.60798937221963845),
#  ('melodrama', 0.60749173598145145),
#  ('rough', 0.60613580357031549),
#  ('charismatic', 0.60613580357031549),
#  ('peoples', 0.60613580357031549),
#  ('dealing', 0.60517840761398811),
#  ('fine', 0.60496962268013299),
#  ('tap', 0.60391604683200273),
#  ('trio', 0.60157998703445481),
#  ('russell', 0.60120968523425966),
#  ('figures', 0.60077386042893011),
#  ('ward', 0.60005675749393339),
#  ('shine', 0.59911823091166894),
#  ('brady', 0.59911823091166894),
#  ('job', 0.59845562125168661),
#  ('satisfied', 0.59652034487087369),
#  ('river', 0.59637962862495086),
#  ('brown', 0.595773016534769),
#  ('believable', 0.59566072133302495),
#  ('always', 0.59470710774669278),
#  ('bound', 0.59470710774669278),
#  ('hall', 0.5933967777928858),
#  ('cook', 0.5916777203950857),
#  ('claire', 0.59136448625000293),
#  ('broadway', 0.59033768669372433),
#  ('anna', 0.58778666490211906),
#  ('peace', 0.58628403501758408),
#  ('visually', 0.58539431926349916),
#  ('falk', 0.58525821854876026),
#  ('morality', 0.58525821854876026),
#  ('growing', 0.58466653756587539),
#  ('stood', 0.58314628534561685),
#  ('experiences', 0.58314628534561685),
#  ('touch', 0.58122926435596001),
#  ('lives', 0.5810976767513224),
#  ('kubrick', 0.58066919713325493),
#  ('timing', 0.58047401805583243),
#  ('struggles', 0.57981849525294216),
#  ('expressions', 0.57981849525294216),
#  ('authentic', 0.57848427223980559),
#  ('helen', 0.57763429343810091),
#  ('pre', 0.57700753064729182),
#  ('quirky', 0.5753641449035618),
#  ('young', 0.57531672344534313),
#  ('inner', 0.57454143815209846),
#  ('mexico', 0.57443087372056334),
#  ('clint', 0.57380042292737909),
#  ('sisters', 0.57286101468544337),
#  ('realism', 0.57226528899949558),
#  ('personalities', 0.5720692490067093),
#  ('french', 0.5720692490067093),
#  ('adventures', 0.57113222999698177),
#  ('surprises', 0.57113222999698177),
#  ('overcome', 0.5697681593994407),
#  ('timothy', 0.56953322459276867),
#  ('tales', 0.56909453188996639),
#  ('war', 0.56843317302781682),
#  ('civil', 0.5679840376059393),
#  ('countries', 0.56737779327091187),
#  ('streep', 0.56710645966458029),
#  ('tradition', 0.56685345523565323),
#  ('oliver', 0.56673325570428668),
#  ('australia', 0.56580775818334383),
#  ('understanding', 0.56531380905006046),
#  ('players', 0.56509525370004821),
#  ('knowing', 0.56489284503626647),
#  ('rogers', 0.56421349718405212),
#  ('suspenseful', 0.56368911332305849),
#  ('variety', 0.56368911332305849),
#  ('true', 0.56281525180810066),
#  ('jr', 0.56220982311246936),
#  ('psychological', 0.56108745854687891),
#  ('branagh', 0.55961578793542266),
#  ('performing', 0.55961578793542266),
#  ('grand', 0.55961578793542266),
#  ('overwhelming', 0.55961578793542266),
#  ('wealth', 0.55961578793542266),
#  ('sent', 0.55961578793542266),
#  ('reminiscent', 0.55961578793542266),
#  ('odds', 0.55961578793542266),
#  ('brothers', 0.55891181043362848),
#  ('howard', 0.55811089675600245),
#  ('david', 0.55693122256475369),
#  ('generation', 0.55628799784274796),
#  ('grow', 0.55612538299565417),
#  ('survival', 0.55594605904646033),
#  ('mainstream', 0.55574731115750231),
#  ('dick', 0.55431073570572953),
#  ('charm', 0.55288175575407861),
#  ('kirk', 0.55278982286502287),
#  ('twists', 0.55244729845681018),
#  ('gangster', 0.55206858230003986),
#  ('jeff', 0.55179306225421365),
#  ('family', 0.55116244510065526),
#  ('tend', 0.55053307336110335),
#  ('thanks', 0.55049088015842218),
#  ('world', 0.54744234723432639),
#  ('sutherland', 0.54743536937855164),
#  ('life', 0.54695514434959924),
#  ('bug', 0.54654370636806993),
#  ('disc', 0.54654370636806993),
#  ('tribute', 0.5455111817538808),
#  ('europe', 0.54522705048332309),
#  ('sacrifice', 0.54430155296238014),
#  ('color', 0.54405127139431109),
#  ('superior', 0.54333490233128523),
#  ('york', 0.54318235866536513),
#  ('pulls', 0.54266622962164945),
#  ('jackson', 0.54232429082536171),
#  ('hearts', 0.54232429082536171),
#  ('enjoy', 0.54124285135906114),
#  ('redemption', 0.54056759296472823),
#  ('madness', 0.540384426007535),
#  ('trial', 0.5389965007326869),
#  ('hamilton', 0.5389965007326869),
#  ('greek', 0.5389965007326869),
#  ('stands', 0.5389965007326869),
#  ('each', 0.5388212312554177),
#  ('faithful', 0.53773307668591508),
#  ('received', 0.5372768098531604),
#  ('jealous', 0.53714293208336406),
#  ('documentaries', 0.53714293208336406),
#  ('different', 0.53709860682460819),
#  ('describes', 0.53680111016925136),
#  ('shorts', 0.53596159703753288),
#  ('brilliance', 0.53551823635636209),
#  ('mountains', 0.53492317534505118),
#  ('share', 0.53408248593025787),
#  ('dealt', 0.53408248593025787),
#  ('explore', 0.53329847961804933),
#  ('providing', 0.53329847961804933),
#  ('series', 0.5325809226575603),
#  ('fellow', 0.5323318289869543),
#  ('loves', 0.53062825106217038),
#  ('roman', 0.53062825106217038),
#  ('revolution', 0.53062825106217038),
#  ('olivier', 0.53062825106217038),
#  ('century', 0.53002783074992665),
#  ('musical', 0.52966871156747064),
#  ('heroic', 0.52925932545482868),
#  ('ironically', 0.52806743020049673),
#  ('approach', 0.52806743020049673),
#  ('temple', 0.52806743020049673),
#  ('moves', 0.5279372642387119),
#  ('gift', 0.52702030968597136),
#  ('julie', 0.52609309589677911),
#  ('tells', 0.52415107836314001),
#  ('radio', 0.52394671172868779),
#  ('uncle', 0.52354439617376536),
#  ('union', 0.52324814376454787),
#  ('deep', 0.52309571635780505),
#  ('reminds', 0.52157841554225237),
#  ('famous', 0.52118841080153722),
#  ('jazz', 0.52053443789295151),
#  ('dennis', 0.51987545928590861),
#  ('epic', 0.51919387343650736),
#  ('adult', 0.519167695083386),
#  ('shows', 0.51915322220375304),
#  ('demons', 0.5191244265806858),
#  ('performed', 0.5191244265806858),
#  ('discovered', 0.51879379341516751),
#  ('eric', 0.51879379341516751),
#  ('youth', 0.5185626062681431),
#  ('human', 0.51851411224987087),
#  ('tarzan', 0.51813827061227724),
#  ('ourselves', 0.51794309153485463),
#  ('wwii', 0.51758240622887042),
#  ('passion', 0.5162164724008671),
#  ('desire', 0.51607497965213445),
#  ('pays', 0.51581316527702981),
#  ('dirty', 0.51557622652458857),
#  ('fox', 0.51557622652458857),
#  ('sympathetic', 0.51546600332249293),
#  ('symbolism', 0.51546600332249293),
#  ('attitude', 0.51530993621331933),
#  ('appearances', 0.51466440007315639),
#  ('jeremy', 0.51466440007315639),
#  ('fun', 0.51439068993048687),
#  ('south', 0.51420972175023116),
#  ('arrives', 0.51409894911095988),
#  ('present', 0.51341965894303732),
#  ('com', 0.51326167856387173),
#  ('smile', 0.51265880484765169),
#  ('ring', 0.51082562376599072),
#  ('carter', 0.51082562376599072),
#  ('alan', 0.51082562376599072),
#  ('fits', 0.51082562376599072),
#  ('aging', 0.51082562376599072),
#  ('visit', 0.51082562376599072),
#  ('provided', 0.51082562376599072),
#  ('countryside', 0.51082562376599072),
#  ('begins', 0.51015650363396647),
#  ('japan', 0.50900578704900468),
#  ('success', 0.50900578704900468),
#  ('accurate', 0.50895471583017893),
#  ('proud', 0.50800474742434931),
#  ('daily', 0.5075946031845443),
#  ('karloff', 0.50724780241810674),
#  ('atmospheric', 0.50724780241810674),
#  ('recently', 0.50714914903668207),
#  ('fu', 0.50704490092608467),
#  ('horrors', 0.50656122497953315),
#  ('finding', 0.50637127341661037),
#  ('lust', 0.5059356384717989),
#  ('hitchcock', 0.50574947073413001),
#  ('among', 0.50334004951332734),
#  ('viewing', 0.50302139827440906),
#  ('shining', 0.50262885656181222),
#  ('investigation', 0.50262885656181222),
#  ('duo', 0.5020919437972361),
#  ('cameron', 0.5020919437972361),
#  ('finds', 0.50128303100539795),
#  ('contemporary', 0.50077528791248915),
#  ('genuine', 0.50046283673044401),
#  ('frightening', 0.49995595152908684),
#  ('plays', 0.49975983848890226),
#  ('age', 0.49941323171424595),
#  ('position', 0.49899116611898781),
#  ('continues', 0.49863035067217237),
#  ('roles', 0.49839716550752178),
#  ('james', 0.49837216269470402),
#  ('individuals', 0.49824684155913052),
#  ('brought', 0.49783842823917956),
#  ('hilarious', 0.49714551986191058),
#  ('brutal', 0.49681488669639234),
#  ('appropriate', 0.49643688631389105),
#  ('dance', 0.49581998314812048),
#  ('helping', 0.49578774640145024),
#  ('answers', 0.49578774640145024),
#  ('league', 0.49578774640145024),
#  ('stunts', 0.49561620510246196),
#  ('traveling', 0.49532143723002542),
#  ('thoroughly', 0.49414593456733524),
#  ('depicted', 0.49317068852726992),
#  ('differences', 0.49247648509779424),
#  ('combination', 0.49247648509779424),
#  ('honor', 0.49247648509779424),
#  ('fully', 0.49213349075383811),
#  ('tracy', 0.49159426183810306),
#  ('battles', 0.49140753790888908),
#  ('possibility', 0.49112055268665822),
#  ('romance', 0.4901589869574316),
#  ('initially', 0.49002249613622745),
#  ('happy', 0.4898997500608791),
#  ('crime', 0.48977221456815834),
#  ('singing', 0.4893852925281213),
#  ('especially', 0.48901267837860624),
#  ('shakespeare', 0.48754793889664511),
#  ('hugh', 0.48729512635579658),
#  ('detail', 0.48609484250827351),
#  ('guide', 0.48550781578170082),
#  ('julia', 0.48550781578170082),
#  ('san', 0.48550781578170082),
#  ('desperation', 0.48550781578170082),
#  ('companion', 0.48550781578170082),
#  ('strongly', 0.48460242866688824),
#  ('necessary', 0.48302334245403883),
#  ('humanity', 0.48265474679929443),
#  ('drama', 0.48221998493060503),
#  ('warming', 0.48183808689273838),
#  ('intrigue', 0.48183808689273838),
#  ('nonetheless', 0.48183808689273838),
#  ('cuba', 0.48183808689273838),
#  ('planned', 0.47957308026188628),
#  ('pictures', 0.47929937011921681),
#  ('broadcast', 0.47849024312305422),
#  ('nine', 0.47803580094299974),
#  ('settings', 0.47743860773325364),
#  ('history', 0.47732966933780852),
#  ('ordinary', 0.47725880012690741),
#  ('trade', 0.47692407209030935),
#  ('official', 0.47608267532211779),
#  ('primary', 0.47608267532211779),
#  ('episode', 0.47529620261150429),
#  ('role', 0.47520268270188676),
#  ('spirit', 0.47477690799839323),
#  ('grey', 0.47409361449726067),
#  ('ways', 0.47323464982718205),
#  ('cup', 0.47260441094579297),
#  ('piano', 0.47260441094579297),
#  ('familiar', 0.47241617565111949),
#  ('sinister', 0.47198579044972683),
#  ('reveal', 0.47171449364936496),
#  ('max', 0.47150852042515579),
#  ('dated', 0.47121648567094482),
#  ('vicious', 0.47000362924573563),
#  ('discovery', 0.47000362924573563),
#  ('losing', 0.47000362924573563),
#  ('genuinely', 0.46871413841586385),
#  ('hatred', 0.46734051182625186),
#  ('mistaken', 0.46702300110759781),
#  ('dream', 0.46608972992459924),
#  ('challenge', 0.46608972992459924),
#  ('crisis', 0.46575733836428446),
#  ('photographed', 0.46488852857896512),
#  ('critics', 0.46430560813109778),
#  ('bird', 0.46430560813109778),
#  ('machines', 0.46430560813109778),
#  ('born', 0.46411383518967209),
#  ('detective', 0.4636633473511525),
#  ('higher', 0.46328467899699055),
#  ('inevitable', 0.46262352194811296),
#  ('remains', 0.46262352194811296),
#  ('soviet', 0.4618180446592961),
#  ('ryan', 0.46134556650262099),
#  ('african', 0.46112595521371813),
#  ('smaller', 0.46081520319132935),
#  ('techniques', 0.46052488529119184),
#  ('information', 0.46034171833399862),
#  ('deserved', 0.45999798712841444),
#  ('cynical', 0.45953232937844013),
#  ('spielberg', 0.45953232937844013),
#  ('lynch', 0.45953232937844013),
#  ('francisco', 0.45953232937844013),
#  ('tour', 0.45953232937844013),
#  ('struggle', 0.45911782160048453),
#  ('language', 0.45902121257712653),
#  ('visual', 0.45823514408822852),
#  ('warner', 0.45724137763188427),
#  ('social', 0.45720078250735313),
#  ('reality', 0.45719346885019546),
#  ('hidden', 0.45675840249571492),
#  ('breaking', 0.45601738727099561),
#  ('sometimes', 0.45563021171182794),
#  ('modern', 0.45500247579345005),
#  ('surfing', 0.45425527227759638),
#  ('popular', 0.45410691533051023),
#  ('surprised', 0.4534409399850382),
#  ('follows', 0.45245361754408348),
#  ('keeps', 0.45234869400701483),
#  ('john', 0.4520909494482197),
#  ('mixed', 0.45198512374305722),
#  ('defeat', 0.45198512374305722),
#  ('justice', 0.45142724367280018),
#  ('treasure', 0.45083371313801535),
#  ('presents', 0.44973793178615257),
#  ('years', 0.44919197032104968),
#  ('chief', 0.44895022004790319),
#  ('shadows', 0.44802472252696035),
#  ('segments', 0.44701411102103689),
#  ('closely', 0.44701411102103689),
#  ('lose', 0.44658335503763702),
#  ('caine', 0.44628710262841953),
#  ('caught', 0.44610275383999071),
#  ('hamlet', 0.44558510189758965),
#  ('chinese', 0.44507424620321018),
#  ('welcome', 0.44438052435783792),
#  ('birth', 0.44368632092836219),
#  ('represents', 0.44320543609101143),
#  ('puts', 0.44279106572085081),
#  ('visuals', 0.44183275227903923),
#  ('web', 0.44183275227903923),
#  ('closer', 0.44183275227903923),
#  ('fame', 0.44183275227903923),
#  ('criminal', 0.4412745608048752),
#  ('minor', 0.4409224199448939),
#  ('jon', 0.44086703515908027),
#  ('liked', 0.44074991514020723),
#  ('restaurant', 0.44031183943833246),
#  ('de', 0.43983275161237217),
#  ('flaws', 0.43983275161237217),
#  ('searching', 0.4393666597838457),
#  ('rap', 0.43891304217570443),
#  ('light', 0.43884433018199892),
#  ('elizabeth', 0.43872232986464677),
#  ('marry', 0.43861731542506488),
#  ('controversial', 0.43825493093115531),
#  ('oz', 0.43825493093115531),
#  ('learned', 0.43825493093115531),
#  ('slowly', 0.43785660389939979),
#  ('wayne', 0.43721380642274466),
#  ('thrilling', 0.43721380642274466),
#  ('comedic', 0.43721380642274466),
#  ('bridge', 0.43721380642274466),
#  ('married', 0.43658501682196887),
#  ('nazi', 0.4361020775700542),
#  ('physical', 0.4353180712578455),
#  ('murder', 0.4353180712578455),
#  ('johnny', 0.43483971678806865),
#  ('michelle', 0.43445264498141672),
#  ('wallace', 0.43403848055222038),
#  ('comedies', 0.43395706390247063),
#  ('silent', 0.43395706390247063),
#  ('played', 0.43387244114515305),
#  ('international', 0.43363598507486073),
#  ('vision', 0.43286408229627887),
#  ('intelligent', 0.43196704885367099),
#  ('shop', 0.43078291609245434),
#  ('also', 0.43036720209769169),
#  ('levels', 0.4302451371066513),
#  ('miss', 0.43006426712153217),
#  ('ocean', 0.4295626596872249),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]
# Out:
# [('boll', -4.0778152602708904),
#  ('uwe', -3.9218753018711578),
#  ('seagal', -3.3202501058581921),
#  ('unwatchable', -3.0269848170580955),
#  ('stinker', -2.9876839403711624),
#  ('mst', -2.7753833211707968),
#  ('incoherent', -2.7641396677532537),
#  ('unfunny', -2.5545257844967644),
#  ('waste', -2.4907515123361046),
#  ('blah', -2.4475792789485005),
#  ('horrid', -2.3715779644809971),
#  ('pointless', -2.3451073877136341),
#  ('atrocious', -2.3187369339642556),
#  ('redeeming', -2.2667790015910296),
#  ('prom', -2.2601040980178784),
#  ('drivel', -2.2476029585766928),
#  ('lousy', -2.2118080125207054),
#  ('worst', -2.1930856334332267),
#  ('laughable', -2.172468615469592),
#  ('awful', -2.1385076866397488),
#  ('poorly', -2.1326133844207011),
#  ('wasting', -2.1178155545614512),
#  ('remotely', -2.111046881095167),
#  ('existent', -2.0024805005437076),
#  ('boredom', -1.9241486572738005),
#  ('miserably', -1.9216610938019989),
#  ('sucks', -1.9166645809588516),
#  ('uninspired', -1.9131499212248517),
#  ('lame', -1.9117232884159072),
#  ('insult', -1.9085323769376259)]

# %% [markdown]
# # Transforming Text into Numbers

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data

# %%
vocab = set(total_counts.keys())
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %%
list(vocab)
# Out:
# ['',
#  'welliver',
#  'figured',
#  'drink',
#  'candies',
#  'anatomie',
#  'engineers',
#  'beserk',
#  'holoband',
#  'hercule',
#  'optional',
#  'windom',
#  'biding',
#  'wards',
#  'sustains',
#  'maudette',
#  'niamh',
#  'bonny',
#  'hitchhike',
#  'linehan',
#  'treasured',
#  'grandmama',
#  'cthd',
#  'pricked',
#  'chastened',
#  'widowhood',
#  'credibly',
#  'layering',
#  'guiol',
#  'sasha',
#  'pistilli',
#  'bmacv',
#  'mellowed',
#  'slip',
#  'mathematically',
#  'khufu',
#  'harbors',
#  'kern',
#  'theologian',
#  'broughton',
#  'celibacy',
#  'valedictorian',
#  'fly',
#  'orderedby',
#  'budakon',
#  'nou',
#  'deply',
#  'teahupoo',
#  'bands',
#  'dealers',
#  'moonwalk',
#  'popeil',
#  'gasoline',
#  'anonymously',
#  'adventists',
#  'lucile',
#  'schmaltzy',
#  'pumb',
#  'dekhne',
#  'yoshinoya',
#  'riffling',
#  'untie',
#  'terrorise',
#  'bystander',
#  'domesticity',
#  'fjernsynsteatret',
#  'surrey',
#  'narcisstic',
#  'cineliterate',
#  'broomsticks',
#  'joker',
#  'mccenna',
#  'requirements',
#  'unmentionable',
#  'tougher',
#  'spiders',
#  'bahiyyaji',
#  'mehki',
#  'cadillac',
#  'merits',
#  'paints',
#  'bettering',
#  'peeew',
#  'ryunosuke',
#  'illusory',
#  'cher',
#  'bedknobs',
#  'exclusion',
#  'bandalier',
#  'horrorfest',
#  'laureen',
#  'leaveever',
#  'fizzlybear',
#  'unescapable',
#  'awe',
#  'ga',
#  'vacuous',
#  'persoanlly',
#  'mikhail',
#  'majyo',
#  'leticia',
#  'gangreen',
#  'somme',
#  'apocalyptic',
#  'cornwell',
#  'dispassionate',
#  'guinneapig',
#  'intercontinental',
#  'swollen',
#  'innkeeper',
#  'colombian',
#  'beheads',
#  'courtland',
#  'detecting',
#  'appended',
#  'raters',
#  'keeler',
#  'prado',
#  'suction',
#  'fixtures',
#  'watchosky',
#  'coahuila',
#  'glob',
#  'tat',
#  'seating',
#  'unplayable',
#  'combs',
#  'orchids',
#  'disordered',
#  'morisette',
#  'eats',
#  'sidekicks',
#  'papamoschou',
#  'dissolute',
#  'celoron',
#  'koaho',
#  'exhaling',
#  'unsuspected',
#  'tungtvannet',
#  'sophisticated',
#  'linchpin',
#  'isles',
#  'churchill',
#  'toler',
#  'montplaisir',
#  'laxitive',
#  'peaks',
#  'stupifying',
#  'jaclyn',
#  'panther',
#  'rancid',
#  'stubbornly',
#  'milland',
#  'predicable',
#  'relearn',
#  'guested',
#  'outcome',
#  'alabama',
#  'samundar',
#  'kemble',
#  'sparsely',
#  'bookended',
#  'neagle',
#  'stab',
#  'decodes',
#  'impassive',
#  'bristol',
#  'necessitated',
#  'dummheit',
#  'rightness',
#  'statements',
#  'vachtangi',
#  'stepmotherhood',
#  'toxic',
#  'extricates',
#  'coax',
#  'dashiel',
#  'newcombe',
#  'aestheically',
#  'earthworm',
#  'fishes',
#  'formats',
#  'temptate',
#  'youssef',
#  'torv',
#  'constantly',
#  'spitied',
#  'wiseguy',
#  'seiryuu',
#  'stella',
#  'liswood',
#  'projects',
#  'falter',
#  'manouever',
#  'obfuscatedthread',
#  'recipe',
#  'awakens',
#  'astronomically',
#  'authority',
#  'portfolios',
#  'overbite',
#  'electrically',
#  'purile',
#  'zombified',
#  'dusky',
#  'insulted',
#  'handling',
#  'misfortune',
#  'apologizing',
#  'cobalt',
#  'nightstalker',
#  'killbill',
#  'ismay',
#  'moore',
#  'mcmichael',
#  'planter',
#  'sarlacc',
#  'harron',
#  'barring',
#  'rodman',
#  'kunal',
#  'liaison',
#  'thong',
#  'consistent',
#  'insides',
#  'serendipity',
#  'implosion',
#  'larissa',
#  'crockett',
#  'pavle',
#  'radars',
#  'regina',
#  'bakshi',
#  'naddel',
#  'paled',
#  'resolutely',
#  'trudie',
#  'whitlock',
#  'sharpville',
#  'leeson',
#  'olathe',
#  'monetary',
#  'appalachians',
#  'newmail',
#  'ultramodern',
#  'croaking',
#  'publicly',
#  'stretches',
#  'faruza',
#  'exclusive',
#  'interbreed',
#  'snook',
#  'dsv',
#  'ripe',
#  'gunned',
#  'ghunguroo',
#  'yui',
#  'coster',
#  'filet',
#  'misdemeanours',
#  'symbolic',
#  'abetting',
#  'bettany',
#  'riffer',
#  'scented',
#  'transylvanian',
#  'ivresse',
#  'caprios',
#  'tvnz',
#  'bucket',
#  'amaze',
#  'gillen',
#  'jun',
#  'participating',
#  'lumpens',
#  'wippleman',
#  'steadicams',
#  'boobie',
#  'rocketry',
#  'lanford',
#  'starred',
#  'everday',
#  'start',
#  'tormei',
#  'cleancut',
#  'maryam',
#  'viren',
#  'hardcastle',
#  'inarritu',
#  'avoid',
#  'solver',
#  'jarrell',
#  'staden',
#  'phyton',
#  'cohen',
#  'gteborg',
#  'homing',
#  'douchet',
#  'alosio',
#  'assigns',
#  'synapse',
#  'macnamara',
#  'christened',
#  'hypercube',
#  'rehash',
#  'artifice',
#  'schwarzenneger',
#  'displays',
#  'comeon',
#  'confections',
#  'muoz',
#  'nonconformism',
#  'declarative',
#  'greys',
#  'mics',
#  'ligabue',
#  'manouvres',
#  'latitude',
#  'briish',
#  'affiliate',
#  'ctrlc',
#  'mcintyre',
#  'placeholder',
#  'entwined',
#  'aving',
#  'serge',
#  'alpha',
#  'kathleen',
#  'awww',
#  'widdle',
#  'wuornos',
#  'isolated',
#  'surya',
#  'hiker',
#  'peeling',
#  'thenali',
#  'cruse',
#  'manfred',
#  'reprinted',
#  'spiritualized',
#  'youthfulness',
#  'simms',
#  'carefree',
#  'squadrons',
#  'donaggio',
#  'brace',
#  'inspirational',
#  'sciences',
#  'gladiator',
#  'unrelievedly',
#  'smita',
#  'holden',
#  'bregman',
#  'customer',
#  'catalog',
#  'bleu',
#  'battering',
#  'crimminy',
#  'greenhouse',
#  'baroque',
#  'ulysses',
#  'mooch',
#  'kibbutz',
#  'deceptiveness',
#  'mold',
#  'selflessness',
#  'rabies',
#  'truest',
#  'ply',
#  'complacent',
#  'sweeping',
#  'signifying',
#  'creeper',
#  'stagecoaches',
#  'scoping',
#  'levan',
#  'ambiguities',
#  'impudence',
#  'yau',
#  'giulio',
#  'irs',
#  'conspiring',
#  'ryoga',
#  'musalman',
#  'centipede',
#  'elope',
#  'weirdest',
#  'coffeshop',
#  'pickpocket',
#  'scotsmen',
#  'anguish',
#  'enabling',
#  'pacingly',
#  'niggles',
#  'designates',
#  'burping',
#  'frederic',
#  'hypocrites',
#  'total',
#  'winterbolt',
#  'sketchily',
#  'surge',
#  'cusack',
#  'piscopo',
#  'chenoweth',
#  'kaite',
#  'britishness',
#  'chest',
#  'treaty',
#  'carolers',
#  'grifts',
#  'throuout',
#  'deflate',
#  'followings',
#  'puppet',
#  'waterfall',
#  'giamatti',
#  'wathced',
#  'phillipe',
#  'kent',
#  'extensions',
#  'tm',
#  'tautou',
#  'iphigenia',
#  'rockwell',
#  'repentance',
#  'blinkered',
#  'regurgitate',
#  'magnesium',
#  'juicier',
#  'prost',
#  'muzzy',
#  'catelain',
#  'masquerading',
#  'furiously',
#  'difford',
#  'repulsively',
#  'airmen',
#  'skewing',
#  'ruthlessness',
#  'selfloathing',
#  'draper',
#  'binouche',
#  'poof',
#  'skipable',
#  'solondz',
#  'perform',
#  'sortie',
#  'archiological',
#  'subways',
#  'disrobed',
#  'conundrums',
#  'iran',
#  'pakeza',
#  'infiniti',
#  'otooles',
#  'slobber',
#  'ifc',
#  'ayats',
#  'oppose',
#  'medias',
#  'spacecamp',
#  'itelf',
#  'scriptwise',
#  'cobbling',
#  'omits',
#  'aboriginal',
#  'assurance',
#  'errr',
#  'psp',
#  'navel',
#  'age',
#  'artist',
#  'tracked',
#  'outdated',
#  'baja',
#  'dreck',
#  'anticipate',
#  'striba',
#  'teen',
#  'vocation',
#  'pinky',
#  'amputated',
#  'edges',
#  'spilt',
#  'mellowy',
#  'disparate',
#  'vadis',
#  'francisca',
#  'barrages',
#  'matre',
#  'chalon',
#  'snuka',
#  'petr',
#  'capt',
#  'jochen',
#  'idolatry',
#  'olyphant',
#  'fadeouts',
#  'corman',
#  'precipitating',
#  'circulations',
#  'roshambo',
#  'habit',
#  'ripen',
#  'painkiller',
#  'hermit',
#  'creds',
#  'strombel',
#  'tellings',
#  'summed',
#  'sonarman',
#  'blackstar',
#  'woad',
#  'edition',
#  'rap',
#  'obnoxious',
#  'vanishing',
#  'leit',
#  'forebodings',
#  'alex',
#  'dawdling',
#  'hamari',
#  'metaphores',
#  'dictators',
#  'reworks',
#  'miyan',
#  'dieing',
#  'smacko',
#  'madelein',
#  'henley',
#  'troyepolsky',
#  'programmed',
#  'crossroad',
#  'stripper',
#  'wiking',
#  'tipped',
#  'cloistered',
#  'retell',
#  'stockler',
#  'stalker',
#  'dias',
#  'fanfare',
#  'fulminating',
#  'burgi',
#  'woe',
#  'kingdoms',
#  'evidences',
#  'tore',
#  'blech',
#  'diry',
#  'zukhov',
#  'brendon',
#  'jaffrey',
#  'pondering',
#  'nuremberg',
#  'gregoire',
#  'regret',
#  'underscores',
#  'skin',
#  'collapsed',
#  'everyman',
#  'airlift',
#  'shakingly',
#  'wails',
#  'cinematographe',
#  'sneeze',
#  'peppy',
#  'treacher',
#  'grandparents',
#  'goldman',
#  'helpers',
#  'survive',
#  'unsuprised',
#  'rna',
#  'petites',
#  'mendanassos',
#  'feeble',
#  'horticultural',
#  'griswolds',
#  'hunchul',
#  'waldo',
#  'rattler',
#  'uterus',
#  'lol',
#  'buffy',
#  'dardino',
#  'danse',
#  'monoliths',
#  'begly',
#  'newt',
#  'bedpost',
#  'intersperses',
#  'strict',
#  'bechlar',
#  'joshuatree',
#  'accountancy',
#  'kalamazoo',
#  'mammonist',
#  'privileged',
#  'cohabiting',
#  'contraire',
#  'halve',
#  'underdog',
#  'mail',
#  'jammed',
#  'typhoid',
#  'gush',
#  'torino',
#  'riedelsheimer',
#  'icon',
#  'insectoid',
#  'samira',
#  'neuroses',
#  'overlaps',
#  'travesty',
#  'koreans',
#  'unnervingly',
#  'barbers',
#  'videowork',
#  'squishing',
#  'cassetti',
#  'clay',
#  'feierstein',
#  'commercialisation',
#  'overblow',
#  'hypnotizing',
#  'thuggee',
#  'manages',
#  'resoundingly',
#  'diffring',
#  'mutants',
#  'trinidad',
#  'processor',
#  'gjon',
#  'yewbenighted',
#  'sickle',
#  'wpix',
#  'commits',
#  'victimizing',
#  'reyes',
#  'usmc',
#  'sandlers',
#  'zim',
#  'consultation',
#  'adultry',
#  'meteorite',
#  'mastriosimone',
#  'interview',
#  'buttons',
#  'suckers',
#  'fantasia',
#  'elevate',
#  'indecisively',
#  'yokel',
#  'feral',
#  'malini',
#  'intruded',
#  'prose',
#  'macleod',
#  'barrier',
#  'jeannot',
#  'demille',
#  'deportees',
#  'campaigns',
#  'redundancies',
#  'imagined',
#  'choti',
#  'consults',
#  'thibeau',
#  'jarre',
#  'underestimates',
#  'wannabees',
#  'latches',
#  'poky',
#  'albertson',
#  'diseased',
#  'bamboo',
#  'enduring',
#  'expect',
#  'unsweaty',
#  'langara',
#  'miryang',
#  'articulated',
#  'boaters',
#  'missiles',
#  'galvanize',
#  'greendale',
#  'coulthard',
#  'cramer',
#  'parsi',
#  'dosen',
#  'zan',
#  'varda',
#  'blackend',
#  'weinbauer',
#  'exaggerate',
#  'southeastern',
#  'larrazabal',
#  'hi',
#  'disgrace',
#  'disquiet',
#  'bancroft',
#  'coos',
#  'choppy',
#  'cbs',
#  'blvd',
#  'idiosyncrasy',
#  'mcgwire',
#  'nonproportionally',
#  'posit',
#  'conquers',
#  'salaries',
#  'decadence',
#  'pants',
#  'kher',
#  'dwar',
#  'honing',
#  'bummed',
#  'cannon',
#  'lifes',
#  'khakhee',
#  'japnanese',
#  'oracle',
#  'quickliy',
#  'frenetic',
#  'vies',
#  'henleys',
#  'michaelango',
#  'centerers',
#  'denzel',
#  'lasky',
#  'admitedly',
#  'boarding',
#  'magoo',
#  'songdances',
#  'lamia',
#  'larcenous',
#  'blithe',
#  'weariness',
#  'creeps',
#  'gowns',
#  'pantheism',
#  'puppets',
#  'jianxiang',
#  'umi',
#  'tambien',
#  'hypercritical',
#  'decoration',
#  'du',
#  'laustsen',
#  'baits',
#  'bratt',
#  'blair',
#  'hounslow',
#  'einstein',
#  'mccall',
#  'hoon',
#  'investigatory',
#  'elephantsfar',
#  'massiah',
#  'chooses',
#  'phyllida',
#  'kaoru',
#  'fussbudget',
#  'brought',
#  'eggbeater',
#  'katzir',
#  'wiles',
#  'perlman',
#  'leni',
#  'trolls',
#  'delusive',
#  'synopsizing',
#  'collosus',
#  'papery',
#  'discriminate',
#  'rouncewell',
#  'pessimistic',
#  'acquiescence',
#  'guerin',
#  'fires',
#  'localized',
#  'spratt',
#  'fishhooks',
#  'christopher',
#  'rivalskeaton',
#  'gardenia',
#  'ninnies',
#  'stig',
#  'beast',
#  'diversion',
#  'slowing',
#  'roughnecks',
#  'overlooks',
#  'ameche',
#  'input',
#  'larroquette',
#  'waite',
#  'cornrows',
#  'ingram',
#  'blackmailer',
#  'rennes',
#  'comas',
#  'caste',
#  'glowed',
#  'drexler',
#  'intercedes',
#  'hidegarishous',
#  'disproportionately',
#  'rummenigge',
#  'soubrette',
#  'thatseriously',
#  'tomassi',
#  'belenguer',
#  'irrefutably',
#  'paragon',
#  'johanne',
#  'parkey',
#  'numbingly',
#  'moralism',
#  'subjectively',
#  'dicken',
#  'thumbs',
#  'shamrock',
#  'apossibly',
#  'amilee',
#  'pastry',
#  'tanaaz',
#  'klaus',
#  'lasso',
#  'devito',
#  'rockfalls',
#  'imaginaire',
#  'altar',
#  'strongbox',
#  'province',
#  'slowmo',
#  'meaning',
#  'carries',
#  'facets',
#  'kaldwell',
#  'brusqueness',
#  'overzealous',
#  'cherished',
#  'battle',
#  'alana',
#  'luque',
#  'flown',
#  'burp',
#  'devoy',
#  'leads',
#  'westernized',
#  'outlandish',
#  'earls',
#  'bassis',
#  'castrated',
#  'maclagan',
#  'whaling',
#  'baskervilles',
#  'vivre',
#  'oxbow',
#  'excrete',
#  'verheyen',
#  'commando',
#  'studied',
#  'speckled',
#  'jafri',
#  'dislikably',
#  'misato',
#  'koyuki',
#  'curable',
#  'rwandan',
#  'yakuza',
#  'himalaya',
#  'numbskulls',
#  'vohra',
#  'differentiation',
#  'boondocks',
#  'flowers',
#  'baddie',
#  'strap',
#  'lilith',
#  'goldie',
#  'mcdoakes',
#  'imbecile',
#  'planetscapes',
#  'contextualized',
#  'empowering',
#  'dysney',
#  'jonesy',
#  'debyt',
#  'simmon',
#  'machination',
#  'pryors',
#  'heathcliff',
#  'usury',
#  'dub',
#  'nekron',
#  'pretzel',
#  'sbs',
#  'smearing',
#  'deduction',
#  'pallbearer',
#  'dismaying',
#  'woven',
#  'bartleby',
#  'procedures',
#  'moderator',
#  'gujerati',
#  'synthetic',
#  'liev',
#  'yakin',
#  'campily',
#  'jenner',
#  'enright',
#  'risked',
#  'limbs',
#  'famdamily',
#  'reduction',
#  'g',
#  'rebroadcast',
#  'ubasti',
#  'starsailor',
#  'kkk',
#  'reject',
#  'gryll',
#  'lin',
#  'overrunning',
#  'uninhibitedly',
#  'concentrating',
#  'pearce',
#  'heisenberg',
#  'y',
#  'problems',
#  'detritus',
#  'unused',
#  'washer',
#  'lumbers',
#  'megalomanic',
#  'shoppingmal',
#  'angora',
#  'symphonies',
#  'burdened',
#  'diplomats',
#  'ungallantly',
#  'multimedia',
#  'gothika',
#  'devaluation',
#  'wowed',
#  'stumbling',
#  'telepath',
#  'astral',
#  'persecuted',
#  'marseilles',
#  'bocanegra',
#  'manhatten',
#  'boating',
#  'partner',
#  'kawai',
#  'ruin',
#  'traumatizing',
#  'durya',
#  'corto',
#  'scoring',
#  'ribsi',
#  'characterize',
#  'competed',
#  'binev',
#  'survivable',
#  'disc',
#  'wouters',
#  'hilariously',
#  'untergang',
#  'warranted',
#  'beefheart',
#  'empowerment',
#  'ungar',
#  'pleading',
#  'servers',
#  'returns',
#  'dare',
#  'tormento',
#  'expendable',
#  'laboratory',
#  'shoebox',
#  'transvestism',
#  'prepubescent',
#  'mechapiloting',
#  'beadle',
#  'connotations',
#  'technicalities',
#  'opportunities',
#  'ignominious',
#  'marrying',
#  'coolidge',
#  'bootleg',
#  'klara',
#  'amusingly',
#  'fruitless',
#  ...]

# %%
import numpy as np

layer_0 = np.zeros((1,vocab_size))
layer_0
# Out:
# array([[ 0.,  0.,  0., ...,  0.,  0.,  0.]])

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
word2index = {}

for i,word in enumerate(vocab):
    word2index[word] = i
word2index
# Out:
# {'': 0,
#  'welliver': 1,
#  'figured': 2,
#  'drink': 3,
#  'candies': 4,
#  'anatomie': 5,
#  'engineers': 6,
#  'beserk': 7,
#  'holoband': 8,
#  'hercule': 9,
#  'optional': 10,
#  'exwife': 49604,
#  'biding': 12,
#  'wards': 13,
#  'unsupervised': 68464,
#  'sustains': 14,
#  'maudette': 15,
#  'niamh': 16,
#  'bonny': 17,
#  'hitchhike': 18,
#  'linehan': 19,
#  'covers': 24810,
#  'treasured': 20,
#  'attonment': 12377,
#  'grandmama': 21,
#  'cthd': 22,
#  'pricked': 23,
#  'chastened': 24,
#  'downturn': 60595,
#  'credibly': 26,
#  'nausicaa': 24816,
#  'crickets': 33166,
#  'guiol': 28,
#  'sasha': 29,
#  'pistilli': 30,
#  'bmacv': 31,
#  'mathematically': 34,
#  'slip': 33,
#  'khufu': 35,
#  'harbors': 36,
#  'kern': 37,
#  'linenone': 17835,
#  'broughton': 39,
#  'celibacy': 40,
#  'valedictorian': 41,
#  'fly': 42,
#  'orderedby': 43,
#  'budakon': 44,
#  'windom': 11,
#  'deply': 46,
#  'teahupoo': 47,
#  'bands': 48,
#  'icier': 25354,
#  'dealers': 49,
#  'moonwalk': 50,
#  'untie': 61,
#  'anonymously': 53,
#  'adventists': 54,
#  'dispute': 24820,
#  'pumb': 57,
#  'topor': 49613,
#  'yoshinoya': 59,
#  'riffling': 60,
#  'domesticity': 64,
#  'bystander': 63,
#  'surrey': 66,
#  'leveraging': 68423,
#  'cineliterate': 68,
#  'joker': 70,
#  'mccenna': 71,
#  'requirements': 72,
#  'unmentionable': 73,
#  'tougher': 74,
#  'spiders': 75,
#  'cadillac': 78,
#  'paints': 80,
#  'bettering': 81,
#  'shortchanging': 61843,
#  'ooverall': 62425,
#  'ryunosuke': 83,
#  'illusory': 84,
#  'cher': 85,
#  'bedknobs': 86,
#  'exclusion': 87,
#  'abigail': 37342,
#  'dental': 24827,
#  'emerged': 12381,
#  'bandalier': 88,
#  'horrorfest': 89,
#  'leaveever': 91,
#  'unescapable': 93,
#  'awe': 94,
#  'tinsletown': 72510,
#  'ga': 95,
#  'vacuous': 96,
#  'persoanlly': 97,
#  'mikhail': 98,
#  'majyo': 99,
#  'leticia': 100,
#  'gangreen': 101,
#  'apocalyptic': 103,
#  'cornwell': 104,
#  'dispassionate': 105,
#  'guinneapig': 106,
#  'intercontinental': 107,
#  'swollen': 108,
#  'recommeded': 12386,
#  'innkeeper': 109,
#  'colombian': 110,
#  'beheads': 111,
#  'courtland': 112,
#  'detecting': 113,
#  'interchanged': 66202,
#  'raters': 115,
#  'keeler': 116,
#  'mostand': 24832,
#  'prado': 117,
#  'suction': 118,
#  'fixtures': 119,
#  'watchosky': 120,
#  'categorically': 61851,
#  'glob': 122,
#  'tat': 123,
#  'unplayable': 125,
#  'imaginably': 55746,
#  'problembrilliant': 29847,
#  'filmmuch': 73647,
#  'combs': 126,
#  'orchids': 127,
#  'disordered': 128,
#  'joked': 64830,
#  'morisette': 129,
#  'eats': 130,
#  'papamoschou': 132,
#  'dissolute': 133,
#  'exhaling': 136,
#  'koaho': 135,
#  'unsuspected': 137,
#  'tungtvannet': 138,
#  'sophisticated': 139,
#  'simpers': 54559,
#  'linchpin': 140,
#  'churchill': 142,
#  'toler': 143,
#  'adventuresome': 37354,
#  'montplaisir': 144,
#  'laxitive': 145,
#  'peaks': 146,
#  'stupifying': 147,
#  'jaclyn': 148,
#  'panther': 149,
#  'warpaint': 12395,
#  'predicable': 153,
#  'relearn': 154,
#  'outcome': 156,
#  'alabama': 157,
#  'samundar': 158,
#  'kemble': 159,
#  'blut': 29269,
#  'sparsely': 160,
#  'bookended': 161,
#  'neagle': 162,
#  'impassive': 165,
#  'decodes': 164,
#  'bristol': 166,
#  'necessitated': 167,
#  'rightness': 169,
#  'statements': 170,
#  'dimensionless': 72277,
#  'vachtangi': 171,
#  'stepmotherhood': 172,
#  'toxic': 173,
#  'extricates': 174,
#  'schooler': 49625,
#  'coax': 175,
#  'dashiel': 176,
#  'newcombe': 177,
#  'siriaque': 12398,
#  'earthworm': 179,
#  'fishes': 180,
#  'passageway': 24844,
#  'youssef': 183,
#  'permutations': 12399,
#  'torv': 184,
#  'constantly': 185,
#  'spitied': 186,
#  'wiseguy': 187,
#  'seiryuu': 188,
#  'stella': 189,
#  'projects': 191,
#  'falter': 192,
#  'manouever': 193,
#  'obfuscatedthread': 194,
#  'awakens': 196,
#  'tossed': 17814,
#  'astronomically': 197,
#  'authority': 198,
#  'overbite': 200,
#  'purile': 202,
#  'zombified': 203,
#  'dusky': 204,
#  'insulted': 205,
#  'handling': 206,
#  'cobalt': 209,
#  'willfulness': 12406,
#  'nightstalker': 210,
#  'killbill': 211,
#  'fowl': 70461,
#  'ismay': 212,
#  'moore': 213,
#  'mcmichael': 214,
#  'theologian': 38,
#  'planter': 215,
#  'sarlacc': 216,
#  'harron': 217,
#  'leartes': 37369,
#  'barring': 218,
#  'rodman': 219,
#  'kunal': 220,
#  'consistent': 223,
#  'thong': 222,
#  'resell': 55666,
#  'shanao': 16243,
#  'wristed': 12413,
#  'insides': 224,
#  'medved': 73776,
#  'blocker': 65349,
#  'serendipity': 225,
#  'implosion': 226,
#  'commissioning': 12416,
#  'mollecular': 45335,
#  'crockett': 228,
#  'pavle': 229,
#  'escape': 44200,
#  'bakshi': 232,
#  'redub': 5789,
#  'naddel': 233,
#  'paled': 234,
#  'resolutely': 235,
#  'appalachians': 242,
#  'leeson': 239,
#  'sharpville': 238,
#  'olathe': 240,
#  'croaking': 245,
#  'newmail': 243,
#  'bakery': 61863,
#  'publicly': 246,
#  'stretches': 247,
#  'faruza': 248,
#  'interbreed': 250,
#  'snook': 251,
#  'ghunguroo': 255,
#  'ripe': 253,
#  'coster': 257,
#  'yui': 256,
#  'anyones': 37375,
#  'filet': 258,
#  'misdemeanours': 259,
#  'symbolic': 260,
#  'bettany': 262,
#  'riffer': 263,
#  'ivresse': 266,
#  'transylvanian': 265,
#  'nou': 45,
#  'caprios': 267,
#  'veritable': 24857,
#  'silence': 68074,
#  'tvnz': 268,
#  'bucket': 269,
#  'alger': 57684,
#  'amaze': 270,
#  'gillen': 271,
#  'jun': 272,
#  'participating': 273,
#  'wippleman': 275,
#  'steadicams': 276,
#  'boobie': 277,
#  'rocketry': 278,
#  'headlined': 49646,
#  'seldomely': 37378,
#  'slump': 67155,
#  'lanford': 279,
#  'popeil': 51,
#  'inflict': 65374,
#  'starred': 280,
#  'copped': 49648,
#  'everday': 281,
#  'start': 282,
#  'tormei': 283,
#  'cleancut': 284,
#  'tipping': 61871,
#  'maryam': 285,
#  'viren': 286,
#  'hardcastle': 287,
#  'inarritu': 288,
#  'arrrghhhhhhs': 24867,
#  'jarrell': 291,
#  'solver': 290,
#  'gasoline': 52,
#  'staden': 292,
#  'homing': 296,
#  'douchet': 297,
#  'assigns': 299,
#  'jos': 12427,
#  'macnamara': 301,
#  'ellery': 61873,
#  'bejebees': 24868,
#  'christened': 302,
#  'honed': 65600,
#  'hypercube': 303,
#  'morhenge': 12429,
#  'exhooker': 28321,
#  'artifice': 305,
#  'schwarzenneger': 306,
#  'manna': 70931,
#  'comeon': 308,
#  'muoz': 310,
#  'declarative': 312,
#  'greys': 313,
#  'mics': 314,
#  'ligabue': 315,
#  'latitude': 317,
#  'briish': 318,
#  'musicals': 34993,
#  'balloon': 12434,
#  'ctrlc': 320,
#  'externalised': 31188,
#  'mcintyre': 321,
#  'skinner': 67274,
#  'placeholder': 322,
#  'entwined': 323,
#  'aving': 324,
#  'serge': 325,
#  'alpha': 326,
#  'kathleen': 327,
#  'awww': 328,
#  'widdle': 329,
#  'wuornos': 330,
#  'isolated': 331,
#  'terrorise': 62,
#  'cruse': 336,
#  'peeling': 334,
#  'manfred': 337,
#  'reprinted': 338,
#  'spiritualized': 339,
#  'pikes': 49659,
#  'youthfulness': 340,
#  'simms': 341,
#  'carefree': 342,
#  'brace': 345,
#  'inspirational': 346,
#  'lve': 49661,
#  'gladiator': 348,
#  'eminent': 54122,
#  'bregman': 352,
#  'magicians': 37392,
#  'customer': 353,
#  'josie': 42360,
#  'bleu': 355,
#  'battering': 356,
#  'crimminy': 357,
#  'greenhouse': 358,
#  'baroque': 359,
#  'ulysses': 360,
#  'isca': 66521,
#  'kibbutz': 362,
#  'deceptiveness': 363,
#  'mold': 364,
#  'selflessness': 365,
#  'speculating': 54719,
#  'narcisstic': 67,
#  'ply': 368,
#  'complacent': 369,
#  'repertoires': 49666,
#  'sweeping': 370,
#  'creeper': 372,
#  'stagecoaches': 373,
#  'napunsaktha': 31262,
#  'scoping': 374,
#  'broomsticks': 69,
#  'impudence': 377,
#  'yau': 378,
#  'ryoga': 382,
#  'irs': 380,
#  'conspiring': 381,
#  'centipede': 384,
#  'elope': 385,
#  'weirdest': 386,
#  'coffeshop': 387,
#  'pickpocket': 388,
#  'scotsmen': 389,
#  'enabling': 391,
#  'incandescent': 24886,
#  'pacingly': 392,
#  'niggles': 393,
#  'traill': 72521,
#  'designates': 394,
#  'ola': 71487,
#  'trompettos': 68313,
#  'burping': 395,
#  'winterbolt': 399,
#  'total': 398,
#  'sketchily': 400,
#  'cusack': 402,
#  'conducted': 24889,
#  'piscopo': 403,
#  'chenoweth': 404,
#  'mehki': 77,
#  'carolers': 409,
#  'chest': 407,
#  'treaty': 408,
#  'grifts': 410,
#  'followings': 413,
#  'gli': 54487,
#  'puppet': 414,
#  'juggling': 24892,
#  'phillipe': 418,
#  'kent': 419,
#  'tm': 421,
#  'tautou': 422,
#  'iphigenia': 423,
#  'rockwell': 424,
#  'repentance': 425,
#  'regurgitate': 427,
#  'magnesium': 428,
#  'prost': 430,
#  'waaaaayyyyyy': 47724,
#  'muzzy': 431,
#  'catelain': 432,
#  'masquerading': 433,
#  'furiously': 434,
#  'difford': 435,
#  'airmen': 437,
#  'skewing': 438,
#  'ruthlessness': 439,
#  'selfloathing': 440,
#  'draper': 441,
#  'binouche': 442,
#  'skipable': 444,
#  'solondz': 445,
#  'perform': 446,
#  'sortie': 447,
#  'archiological': 448,
#  'infiniti': 454,
#  'pakeza': 453,
#  'conundrums': 451,
#  'otooles': 455,
#  'slobber': 456,
#  'ifc': 457,
#  'ayats': 458,
#  'scriptwise': 463,
#  'medias': 460,
#  'spacecamp': 461,
#  'omits': 465,
#  'aboriginal': 466,
#  'bsu': 37409,
#  'rumann': 61897,
#  'errr': 468,
#  'psp': 469,
#  'tarrinno': 61896,
#  'uncouth': 12449,
#  'navel': 470,
#  'age': 471,
#  'tracked': 473,
#  'noin': 30403,
#  'outdated': 474,
#  'baja': 475,
#  'dreck': 476,
#  'anticipate': 477,
#  'striba': 478,
#  'instants': 37414,
#  'pinky': 481,
#  'amputated': 482,
#  'edges': 483,
#  'wans': 53328,
#  'mellowy': 485,
#  'mud': 24904,
#  'disparate': 486,
#  'vadis': 487,
#  'wheels': 61206,
#  'longhetti': 59003,
#  'francisca': 488,
#  'barrages': 489,
#  'matre': 490,
#  'monopolies': 60454,
#  'hupfel': 61900,
#  'chalon': 491,
#  'snuka': 492,
#  'petr': 493,
#  'acting': 49675,
#  'capt': 494,
#  'idolatry': 496,
#  'olyphant': 497,
#  'fadeouts': 498,
#  'circulations': 501,
#  'precipitating': 500,
#  'grieg': 61906,
#  'mattress': 38812,
#  'roshambo': 502,
#  'habit': 503,
#  'painkiller': 505,
#  'hermit': 506,
#  'strombel': 508,
#  'unappealing': 17331,
#  'dei': 37421,
#  'summed': 510,
#  'woad': 513,
#  'sonarman': 511,
#  'blackstar': 512,
#  'edition': 514,
#  'rap': 515,
#  'obnoxious': 516,
#  'leit': 518,
#  'forebodings': 519,
#  'alex': 520,
#  'dawdling': 521,
#  'jobs': 37424,
#  'hamari': 522,
#  'collection': 12458,
#  'laureen': 90,
#  'colt': 62180,
#  'shockumenary': 61909,
#  'godfather': 37426,
#  'reworks': 525,
#  'alumni': 24913,
#  'miyan': 526,
#  'shaadi': 12460,
#  'smacko': 528,
#  'madelein': 529,
#  'henley': 530,
#  'duddy': 64674,
#  'programmed': 532,
#  'jasmin': 28261,
#  'stuntmen': 61912,
#  'crossroad': 533,
#  'stripper': 534,
#  'stockler': 539,
#  'tipped': 536,
#  'cloistered': 537,
#  'retell': 538,
#  'stalker': 540,
#  'fanfare': 542,
#  'fulminating': 543,
#  'burgi': 544,
#  'woe': 545,
#  'prowler': 24914,
#  'tore': 548,
#  'blech': 549,
#  'brendon': 552,
#  'pondering': 554,
#  'nuremberg': 555,
#  'gregoire': 556,
#  'regret': 557,
#  'underscores': 558,
#  'airlift': 562,
#  'everyman': 561,
#  'shakingly': 563,
#  'cinematographe': 565,
#  'analyzer': 57921,
#  'reinventing': 24918,
#  'outriders': 4894,
#  'jindabyne': 18534,
#  'sneeze': 566,
#  'peppy': 567,
#  'grandparents': 569,
#  'helpers': 571,
#  'survive': 572,
#  'unsuprised': 573,
#  'rna': 574,
#  'petites': 575,
#  'waldo': 581,
#  'uterus': 583,
#  'griswolds': 579,
#  'rattler': 582,
#  'lol': 584,
#  'dardino': 586,
#  'danse': 587,
#  'monoliths': 588,
#  'somme': 102,
#  'begly': 589,
#  'crud': 61919,
#  'newt': 590,
#  'oasis': 49699,
#  'strict': 593,
#  'deirdre': 24925,
#  'bechlar': 594,
#  'joshuatree': 595,
#  'accountancy': 596,
#  'kalamazoo': 597,
#  'mammonist': 598,
#  'privileged': 599,
#  'cohabiting': 600,
#  'contraire': 601,
#  'halve': 602,
#  'shapeshifting': 59253,
#  'underdog': 603,
#  'mail': 604,
#  'jammed': 605,
#  'typhoid': 606,
#  'gush': 607,
#  'mole': 37442,
#  'riedelsheimer': 609,
#  'icon': 610,
#  'weitz': 34477,
#  'samira': 612,
#  'neuroses': 613,
#  'overlaps': 614,
#  'travesty': 615,
#  'jailbreak': 61921,
#  'unnervingly': 617,
#  'barbers': 618,
#  'feierstein': 623,
#  'squishing': 620,
#  'cassetti': 621,
#  'clay': 622,
#  'commercialisation': 624,
#  'overblow': 625,
#  'hypnotizing': 626,
#  'thuggee': 627,
#  'diffring': 630,
#  'processor': 633,
#  'glutton': 37446,
#  'mutants': 631,
#  'trinidad': 632,
#  'gjon': 634,
#  'sickle': 636,
#  'appelagate': 30516,
#  'commits': 638,
#  'victimizing': 639,
#  'reyes': 640,
#  'sandlers': 642,
#  'consultation': 644,
#  'adultry': 645,
#  'meteorite': 646,
#  'mastriosimone': 647,
#  'buttons': 649,
#  'kroc': 24931,
#  'fantasia': 651,
#  'elevate': 652,
#  'pluto': 61924,
#  'feral': 655,
#  'malini': 656,
#  'appended': 114,
#  'intruded': 657,
#  'prose': 658,
#  'jeannot': 661,
#  'demille': 662,
#  'deportees': 663,
#  'campaigns': 664,
#  'redundancies': 665,
#  'envious': 12476,
#  'imagined': 666,
#  'choti': 667,
#  'consults': 668,
#  'jarre': 670,
#  'underestimates': 671,
#  'wannabees': 672,
#  'poky': 674,
#  'surfer': 61926,
#  'albertson': 675,
#  'maille': 12479,
#  'diseased': 676,
#  'bamboo': 677,
#  'enduring': 678,
#  'unsweaty': 680,
#  'miryang': 682,
#  'boaters': 684,
#  'galvanize': 686,
#  'pleasent': 12482,
#  'coulthard': 688,
#  'cramer': 689,
#  'parsi': 690,
#  'dosen': 691,
#  'zan': 692,
#  'varda': 693,
#  'blackend': 694,
#  'weinbauer': 695,
#  'exaggerate': 696,
#  'disquiet': 701,
#  'disgrace': 700,
#  'coos': 703,
#  'bancroft': 702,
#  'choppy': 704,
#  'blvd': 706,
#  'profiling': 58466,
#  'nonproportionally': 709,
#  'salaries': 712,
#  'conquers': 711,
#  'decadence': 713,
#  'pants': 714,
#  'dwar': 716,
#  'honing': 717,
#  'coahuila': 121,
#  'hmmmmmmmm': 61934,
#  'cannon': 719,
#  'lifes': 720,
#  'oracle': 723,
#  'whittle': 70514,
#  'quickliy': 724,
#  'frenetic': 725,
#  'henleys': 727,
#  'michaelango': 728,
#  'seating': 124,
#  'lasky': 731,
#  'admitedly': 732,
#  'boarding': 733,
#  'magoo': 734,
#  'songdances': 735,
#  'lamia': 736,
#  'larcenous': 737,
#  'blithe': 738,
#  'weariness': 739,
#  'creeps': 740,
#  'gowns': 741,
#  'pantheism': 742,
#  'puppets': 743,
#  'copiers': 62068,
#  'tambien': 746,
#  'hypercritical': 747,
#  'decoration': 748,
#  'du': 749,
#  'laustsen': 750,
#  'baits': 751,
#  'patronage': 53439,
#  'fresson': 49719,
#  'blair': 753,
#  'hounslow': 754,
#  'einstein': 755,
#  'mccall': 756,
#  'montenegro': 61938,
#  'silvio': 67085,
#  'disorganised': 12492,
#  'investigatory': 758,
#  'roots': 23719,
#  'elephantsfar': 759,
#  'massiah': 760,
#  'fussbudget': 764,
#  'kaoru': 763,
#  'realisator': 41465,
#  'brought': 765,
#  'eggbeater': 766,
#  'katzir': 767,
#  'wiles': 768,
#  'mauro': 37464,
#  'perlman': 769,
#  'leni': 770,
#  'delusive': 772,
#  'synopsizing': 773,
#  'collosus': 774,
#  'schiff': 51229,
#  'discriminate': 776,
#  'rouncewell': 777,
#  'waltzing': 37467,
#  'acquiescence': 779,
#  'befores': 12497,
#  'guerin': 780,
#  'fires': 781,
#  'misnamed': 65000,
#  'localized': 782,
#  'spratt': 783,
#  'folie': 71796,
#  'fishhooks': 784,
#  'christopher': 785,
#  'gardenia': 787,
#  'ninnies': 788,
#  'znaimer': 49726,
#  'alamo': 72761,
#  'stig': 789,
#  'beast': 790,
#  'larroquette': 797,
#  'input': 796,
#  'overlooks': 794,
#  'ameche': 795,
#  'sidekicks': 131,
#  'waite': 798,
#  'shogun': 12504,
#  'cornrows': 799,
#  'ingram': 800,
#  'blackmailer': 801,
#  'gnawed': 49730,
#  'rennes': 802,
#  'comas': 803,
#  'caste': 804,
#  'drexler': 806,
#  'intercedes': 807,
#  'celoron': 134,
#  'thatseriously': 812,
#  'rummenigge': 810,
#  'soubrette': 811,
#  'tomassi': 813,
#  'linguist': 73148,
#  'belenguer': 814,
#  'irrefutably': 815,
#  'paragon': 816,
#  'digressions': 63369,
#  'parkey': 818,
#  'moralism': 820,
#  'subjectively': 821,
#  'dicken': 822,
#  'thumbs': 823,
#  'dunning': 58551,
#  'shamrock': 824,
#  'amilee': 826,
#  'negates': 56287,
#  'cyrus': 63042,
#  'pastry': 827,
#  'tanaaz': 828,
#  'klaus': 829,
#  'lasso': 830,
#  'vinny': 49736,
#  'devito': 831,
#  'maclachlan': 55130,
#  'rockfalls': 832,
#  'imaginaire': 833,
#  'irrelevent': 61950,
#  'strongbox': 835,
#  'province': 836,
#  'slowmo': 837,
#  'meaning': 838,
#  'kaldwell': 841,
#  'facets': 840,
#  'edison': 37482,
#  'brusqueness': 842,
#  'farlan': 18681,
#  'overzealous': 843,
#  'deprived': 37483,
#  'cherished': 844,
#  'battle': 845,
#  'alana': 846,
#  'luque': 847,
#  'matthias': 73871,
#  'subsumed': 54285,
#  'flown': 848,
#  'burp': 849,
#  'baskervilles': 859,
#  'bassis': 855,
#  'westernized': 852,
#  'outlandish': 853,
#  'earls': 854,
#  'castrated': 856,
#  'yeti': 24956,
#  'whaling': 858,
#  'vivre': 860,
#  'oxbow': 861,
#  'excrete': 862,
#  'verheyen': 863,
#  'commando': 864,
#  'studied': 865,
#  'gunshots': 49740,
#  'figueroa': 45791,
#  'speckled': 866,
#  'voluntary': 49743,
#  'jafri': 867,
#  'dislikably': 868,
#  'misato': 869,
#  'koyuki': 870,
#  'curable': 871,
#  'rwandan': 872,
#  'yakuza': 873,
#  'klugman': 63770,
#  'himalaya': 874,
#  'vohra': 876,
#  'boondocks': 878,
#  'interval': 37486,
#  'flowers': 879,
#  'baddie': 880,
#  'freezes': 12518,
#  'strap': 881,
#  'lilith': 882,
#  'goldie': 883,
#  'mcdoakes': 884,
#  'imbecile': 885,
#  'stubbornly': 151,
#  'planetscapes': 886,
#  'contextualized': 887,
#  'luxor': 66650,
#  'empowering': 888,
#  'jonesy': 890,
#  'simmon': 892,
#  'machination': 893,
#  'pryors': 894,
#  'heathcliff': 895,
#  'usury': 896,
#  'pacifying': 44396,
#  'nekron': 898,
#  'sbs': 900,
#  'pallbearer': 903,
#  'deduction': 902,
#  'dismaying': 904,
#  'bartleby': 906,
#  'gujerati': 909,
#  'moderator': 908,
#  'telefair': 21232,
#  'synthetic': 910,
#  'guested': 155,
#  'soutendjik': 27946,
#  'chiselled': 24964,
#  'liev': 911,
#  'yakin': 912,
#  'campily': 913,
#  'enright': 915,
#  'rebroadcast': 921,
#  'limbs': 917,
#  'famdamily': 918,
#  'g': 920,
#  'konec': 62807,
#  'starsailor': 923,
#  'kkk': 924,
#  'christover': 12525,
#  'reject': 925,
#  'tazmainian': 55598,
#  'gryll': 926,
#  'lin': 927,
#  'overrunning': 928,
#  'slapsticky': 40800,
#  'uninhibitedly': 929,
#  'concentrating': 930,
#  'heisenberg': 932,
#  'y': 933,
#  'problems': 934,
#  'detritus': 935,
#  'megalomanic': 939,
#  'lumbers': 938,
#  'shoppingmal': 940,
#  'angora': 941,
#  'burdened': 943,
#  'ungallantly': 945,
#  'wowed': 949,
#  'gothika': 947,
#  'stumbling': 950,
#  'astral': 952,
#  'stringy': 24968,
#  'persecuted': 953,
#  'marseilles': 954,
#  'bocanegra': 955,
#  'manhatten': 956,
#  'germna': 65153,
#  'boating': 957,
#  'partner': 958,
#  'kawai': 959,
#  'ruin': 960,
#  'strives': 60706,
#  'traumatizing': 961,
#  'arrangements': 37502,
#  'durya': 962,
#  'corto': 963,
#  'scoring': 964,
#  'characterize': 966,
#  'erba': 67502,
#  'competed': 967,
#  'binev': 968,
#  'survivable': 969,
#  'warranted': 974,
#  'wouters': 971,
#  'untergang': 973,
#  'beefheart': 975,
#  'firebird': 73799,
#  'empowerment': 976,
#  'topples': 24973,
#  'substandard': 57305,
#  'ungar': 977,
#  'pleading': 978,
#  'boringness': 20068,
#  'ilva': 12534,
#  'servers': 979,
#  'returns': 980,
#  'dare': 981,
#  'expendable': 983,
#  'laboratory': 984,
#  'shoebox': 985,
#  'propster': 61976,
#  'mechapiloting': 988,
#  'virtues': 57168,
#  'beadle': 989,
#  'connotations': 990,
#  'shane': 55220,
#  'technicalities': 991,
#  'ignominious': 993,
#  'threatens': 59060,
#  'plugged': 35546,
#  'marrying': 994,
#  'coolidge': 995,
#  'invaded': 49757,
#  'bootleg': 996,
#  'klara': 997,
#  'amusingly': 998,
#  'fruitless': 999,
#  'worshipped': 1000,
#  'pictorially': 1004,
#  'glorified': 1003,
#  'wrangled': 1005,
#  'mardi': 46674,
#  'nukem': 1016,
#  'prussia': 1008,
#  'facetiousness': 1011,
#  'outbursts': 1010,
#  'bastketball': 1015,
#  'elkaim': 1014,
#  'shootem': 1019,
#  'refer': 1020,
#  ...}

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0
# Out:
# array([[ 18.,   0.,   0., ...,   0.,   0.,   0.]])

# %%
def get_target_for_label(label):
    if(label == 'POSITIVE'):
        return 1
    else:
        return 0

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # Project 3: Building a Neural Network

# %% [markdown]
# - Start with your neural network from the last chapter
# - 3 layer neural network
# - no non-linearity in hidden layer
# - use our functions to create the training data
# - create a "pre_process_data" function to create vocabulary for our training data generating functions
# - modify "train" to train over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch previous week's Udacity Lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (40% Off: **traskud17**)

# %%
import time
import sys
import numpy as np

# Let's tweak our network from before to model these phenomena
class SentimentNetwork:
    def __init__(self, reviews,labels,hidden_nodes = 10, learning_rate = 0.1):
       
        # set our random number generator 
        np.random.seed(1)
    
        self.pre_process_data(reviews, labels)
        
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)
        
        
    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        for review in reviews:
            for word in review.split(" "):
                review_vocab.add(word)
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        for label in labels:
            label_vocab.add(label)
        
        self.label_vocab = list(label_vocab)
        
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        self.word2index = {}
        for i, word in enumerate(self.review_vocab):
            self.word2index[word] = i
        
        self.label2index = {}
        for i, label in enumerate(self.label_vocab):
            self.label2index[label] = i
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Set number of nodes in input, hidden and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Initialize weights
        self.weights_0_1 = np.zeros((self.input_nodes,self.hidden_nodes))
    
        self.weights_1_2 = np.random.normal(0.0, self.output_nodes**-0.5, 
                                                (self.hidden_nodes, self.output_nodes))
        
        self.learning_rate = learning_rate
        
        self.layer_0 = np.zeros((1,input_nodes))
    
        
    def update_input_layer(self,review):

        # clear out previous state, reset the layer to be all 0s
        self.layer_0 *= 0
        for word in review.split(" "):
            if(word in self.word2index.keys()):
                self.layer_0[0][self.word2index[word]] += 1
                
    def get_target_for_label(self,label):
        if(label == 'POSITIVE'):
            return 1
        else:
            return 0
        
    def sigmoid(self,x):
        return 1 / (1 + np.exp(-x))
    
    
    def sigmoid_output_2_derivative(self,output):
        return output * (1 - output)
    
    def train(self, training_reviews, training_labels):
        
        assert(len(training_reviews) == len(training_labels))
        
        correct_so_far = 0
        
        start = time.time()
        
        for i in range(len(training_reviews)):
            
            review = training_reviews[i]
            label = training_labels[i]
            
            #### Implement the forward pass here ####
            ### Forward pass ###

            # Input Layer
            self.update_input_layer(review)

            # Hidden layer
            layer_1 = self.layer_0.dot(self.weights_0_1)

            # Output layer
            layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))

            #### Implement the backward pass here ####
            ### Backward pass ###

            # TODO: Output error
            layer_2_error = layer_2 - self.get_target_for_label(label) # Output layer error is the difference between desired target and actual output.
            layer_2_delta = layer_2_error * self.sigmoid_output_2_derivative(layer_2)

            # TODO: Backpropagated error
            layer_1_error = layer_2_delta.dot(self.weights_1_2.T) # errors propagated to the hidden layer
            layer_1_delta = layer_1_error # hidden layer gradients - no nonlinearity so it's the same as the error

            # TODO: Update the weights
            self.weights_1_2 -= layer_1.T.dot(layer_2_delta) * self.learning_rate # update hidden-to-output weights with gradient descent step
            self.weights_0_1 -= self.layer_0.T.dot(layer_1_delta) * self.learning_rate # update input-to-hidden weights with gradient descent step

            if(np.abs(layer_2_error) < 0.5):
                correct_so_far += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        
        correct = 0
        
        start = time.time()
        
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            reviews_per_second = i / float(time.time() - start)
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                            + "% #Correct:" + str(correct) + " #Tested:" + str(i+1) + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        
        # Input Layer
        self.update_input_layer(review.lower())

        # Hidden layer
        layer_1 = self.layer_0.dot(self.weights_0_1)

        # Output layer
        layer_2 = self.sigmoid(layer_1.dot(self.weights_1_2))
        
        if(layer_2[0] > 0.5):
            return "POSITIVE"
        else:
            return "NEGATIVE"

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %%
# evaluate our model before training (just to show how horrible it is)
mlp.test(reviews[-1000:],labels[-1000:])
# Out:
# Progress:99.8% Speed(reviews/sec):1274.% #Correct:499 #Tested:999 Testing Accuracy:49.9%:0.1% Speed(reviews/sec):27.69% #Correct:1 #Tested:2 Testing Accuracy:50.0%Progress:0.3% Speed(reviews/sec):80.49% #Correct:2 #Tested:4 Testing Accuracy:50.0%Progress:0.5% Speed(reviews/sec):130.0% #Correct:3 #Tested:6 Testing Accuracy:50.0%Progress:0.7% Speed(reviews/sec):174.1% #Correct:4 #Tested:8 Testing Accuracy:50.0%Progress:0.9% Speed(reviews/sec):210.9% #Correct:5 #Tested:10 Testing Accuracy:50.0%Progress:1.1% Speed(reviews/sec):250.1% #Correct:6 #Tested:12 Testing Accuracy:50.0%Progress:1.3% Speed(reviews/sec):284.9% #Correct:7 #Tested:14 Testing Accuracy:50.0%Progress:1.5% Speed(reviews/sec):317.7% #Correct:8 #Tested:16 Testing Accuracy:50.0%Progress:1.7% Speed(reviews/sec):341.1% #Correct:9 #Tested:18 Testing Accuracy:50.0%Progress:1.9% Speed(reviews/sec):371.4% #Correct:10 #Tested:20 Testing Accuracy:50.0%Progress:2.1% Speed(reviews/sec):394.9% #Correct:11 #Tested:22 Testing Accuracy:50.0%Progress:2.3% Speed(reviews/sec):417.1% #Correct:12 #Tested:24 Testing Accuracy:50.0%Progress:2.5% Speed(reviews/sec):436.5% #Correct:13 #Tested:26 Testing Accuracy:50.0%Progress:2.7% Speed(reviews/sec):448.8% #Correct:14 #Tested:28 Testing Accuracy:50.0%Progress:2.9% Speed(reviews/sec):466.9% #Correct:15 #Tested:30 Testing Accuracy:50.0%Progress:3.1% Speed(reviews/sec):484.8% #Correct:16 #Tested:32 Testing Accuracy:50.0%Progress:3.3% Speed(reviews/sec):503.0% #Correct:17 #Tested:34 Testing Accuracy:50.0%Progress:3.5% Speed(reviews/sec):518.5% #Correct:18 #Tested:36 Testing Accuracy:50.0%Progress:3.7% Speed(reviews/sec):534.5% #Correct:19 #Tested:38 Testing Accuracy:50.0%Progress:3.9% Speed(reviews/sec):543.5% #Correct:20 #Tested:40 Testing Accuracy:50.0%Progress:4.1% Speed(reviews/sec):560.3% #Correct:21 #Tested:42 Testing Accuracy:50.0%Progress:4.3% Speed(reviews/sec):564.0% #Correct:22 #Tested:44 Testing Accuracy:50.0%Progress:4.5% Speed(reviews/sec):562.1% #Correct:23 #Tested:46 Testing Accuracy:50.0%Progress:4.7% Speed(reviews/sec):574.1% #Correct:24 #Tested:48 Testing Accuracy:50.0%Progress:4.9% Speed(reviews/sec):584.5% #Correct:25 #Tested:50 Testing Accuracy:50.0%Progress:5.1% Speed(reviews/sec):599.6% #Correct:26 #Tested:52 Testing Accuracy:50.0%Progress:5.3% Speed(reviews/sec):607.3% #Correct:27 #Tested:54 Testing Accuracy:50.0%Progress:5.5% Speed(reviews/sec):622.5% #Correct:28 #Tested:56 Testing Accuracy:50.0%Progress:5.7% Speed(reviews/sec):627.0% #Correct:29 #Tested:58 Testing Accuracy:50.0%Progress:5.9% Speed(reviews/sec):640.5% #Correct:30 #Tested:60 Testing Accuracy:50.0%Progress:6.1% Speed(reviews/sec):645.0% #Correct:31 #Tested:62 Testing Accuracy:50.0%Progress:6.3% Speed(reviews/sec):657.7% #Correct:32 #Tested:64 Testing Accuracy:50.0%Progress:6.5% Speed(reviews/sec):664.8% #Correct:33 #Tested:66 Testing Accuracy:50.0%Progress:6.7% Speed(reviews/sec):676.0% #Correct:34 #Tested:68 Testing Accuracy:50.0%Progress:6.9% Speed(reviews/sec):683.9% #Correct:35 #Tested:70 Testing Accuracy:50.0%Progress:7.1% Speed(reviews/sec):692.4% #Correct:36 #Tested:72 Testing Accuracy:50.0%Progress:7.3% Speed(reviews/sec):704.2% #Correct:37 #Tested:74 Testing Accuracy:50.0%Progress:7.5% Speed(reviews/sec):715.5% #Correct:38 #Tested:76 Testing Accuracy:50.0%Progress:7.7% Speed(reviews/sec):726.7% #Correct:39 #Tested:78 Testing Accuracy:50.0%Progress:7.9% Speed(reviews/sec):737.2% #Correct:40 #Tested:80 Testing Accuracy:50.0%Progress:8.1% Speed(reviews/sec):741.8% #Correct:41 #Tested:82 Testing Accuracy:50.0%Progress:8.3% Speed(reviews/sec):748.5% #Correct:42 #Tested:84 Testing Accuracy:50.0%Progress:8.5% Speed(reviews/sec):756.7% #Correct:43 #Tested:86 Testing Accuracy:50.0%Progress:8.7% Speed(reviews/sec):760.6% #Correct:44 #Tested:88 Testing Accuracy:50.0%Progress:8.9% Speed(reviews/sec):763.4% #Correct:45 #Tested:90 Testing Accuracy:50.0%Progress:9.1% Speed(reviews/sec):770.6% #Correct:46 #Tested:92 Testing Accuracy:50.0%Progress:9.3% Speed(rev ...

# %%
# train the network
mlp.train(reviews[:-1000],labels[:-1000])
# Out:
# Progress:0.0% Speed(reviews/sec):0.0 #Correct:0 #Trained:1 Training Accuracy:0.0%
# Progress:10.4% Speed(reviews/sec):271.9 #Correct:1250 #Trained:2501 Training Accuracy:49.9%s:0.00% Speed(reviews/sec):105.1 #Correct:1 #Trained:3 Training Accuracy:33.3%Progress:0.01% Speed(reviews/sec):148.8 #Correct:2 #Trained:5 Training Accuracy:40.0%Progress:0.02% Speed(reviews/sec):178.3 #Correct:3 #Trained:7 Training Accuracy:42.8%Progress:0.03% Speed(reviews/sec):198.5 #Correct:4 #Trained:9 Training Accuracy:44.4%Progress:0.04% Speed(reviews/sec):212.0 #Correct:5 #Trained:11 Training Accuracy:45.4%Progress:0.05% Speed(reviews/sec):223.4 #Correct:6 #Trained:13 Training Accuracy:46.1%Progress:0.05% Speed(reviews/sec):231.7 #Correct:7 #Trained:15 Training Accuracy:46.6%Progress:0.06% Speed(reviews/sec):237.1 #Correct:8 #Trained:17 Training Accuracy:47.0%Progress:0.07% Speed(reviews/sec):243.5 #Correct:9 #Trained:19 Training Accuracy:47.3%Progress:0.08% Speed(reviews/sec):247.3 #Correct:10 #Trained:21 Training Accuracy:47.6%Progress:0.09% Speed(reviews/sec):251.5 #Correct:11 #Trained:23 Training Accuracy:47.8%Progress:0.1% Speed(reviews/sec):255.8 #Correct:12 #Trained:25 Training Accuracy:48.0%Progress:0.10% Speed(reviews/sec):254.0 #Correct:13 #Trained:27 Training Accuracy:48.1%Progress:0.11% Speed(reviews/sec):253.8 #Correct:14 #Trained:29 Training Accuracy:48.2%Progress:0.12% Speed(reviews/sec):254.9 #Correct:15 #Trained:31 Training Accuracy:48.3%Progress:0.13% Speed(reviews/sec):256.6 #Correct:16 #Trained:33 Training Accuracy:48.4%Progress:0.14% Speed(reviews/sec):257.0 #Correct:17 #Trained:35 Training Accuracy:48.5%Progress:0.15% Speed(reviews/sec):257.4 #Correct:18 #Trained:37 Training Accuracy:48.6%Progress:0.15% Speed(reviews/sec):257.5 #Correct:19 #Trained:39 Training Accuracy:48.7%Progress:0.16% Speed(reviews/sec):258.0 #Correct:20 #Trained:41 Training Accuracy:48.7%Progress:0.17% Speed(reviews/sec):259.7 #Correct:21 #Trained:43 Training Accuracy:48.8%Progress:0.18% Speed(reviews/sec):259.7 #Correct:22 #Trained:45 Training Accuracy:48.8%Progress:0.19% Speed(reviews/sec):261.3 #Correct:23 #Trained:47 Training Accuracy:48.9%Progress:0.2% Speed(reviews/sec):261.7 #Correct:24 #Trained:49 Training Accuracy:48.9%Progress:0.20% Speed(reviews/sec):261.6 #Correct:25 #Trained:51 Training Accuracy:49.0%Progress:0.21% Speed(reviews/sec):260.8 #Correct:26 #Trained:53 Training Accuracy:49.0%Progress:0.22% Speed(reviews/sec):260.3 #Correct:27 #Trained:55 Training Accuracy:49.0%Progress:0.23% Speed(reviews/sec):261.4 #Correct:28 #Trained:57 Training Accuracy:49.1%Progress:0.24% Speed(reviews/sec):260.6 #Correct:29 #Trained:59 Training Accuracy:49.1%Progress:0.25% Speed(reviews/sec):261.9 #Correct:30 #Trained:61 Training Accuracy:49.1%Progress:0.25% Speed(reviews/sec):262.4 #Correct:31 #Trained:63 Training Accuracy:49.2%Progress:0.26% Speed(reviews/sec):262.8 #Correct:32 #Trained:65 Training Accuracy:49.2%Progress:0.27% Speed(reviews/sec):262.4 #Correct:33 #Trained:67 Training Accuracy:49.2%Progress:0.28% Speed(reviews/sec):262.5 #Correct:34 #Trained:69 Training Accuracy:49.2%Progress:0.29% Speed(reviews/sec):261.5 #Correct:35 #Trained:72 Training Accuracy:48.6%Progress:0.30% Speed(reviews/sec):262.3 #Correct:36 #Trained:74 Training Accuracy:48.6%Progress:0.31% Speed(reviews/sec):262.6 #Correct:37 #Trained:76 Training Accuracy:48.6%Progress:0.32% Speed(reviews/sec):263.3 #Correct:38 #Trained:78 Training Accuracy:48.7%Progress:0.32% Speed(reviews/sec):262.9 #Correct:39 #Trained:80 Training Accuracy:48.7%Progress:0.33% Speed(reviews/sec):263.1 #Correct:40 #Trained:82 Training Accuracy:48.7%Progress:0.34% Speed(reviews/sec):263.8 #Correct:41 #Trained:84 Training Accuracy:48.8%Progress:0.35% Speed(reviews/sec):263.4 #Correct:42 #Trained:86 Training Accuracy:48.8%Progress:0.36% Speed(reviews/sec):264.2 #Correct:43 #Trained:88 Training Accuracy:48.8%Progress:0.37% Speed(reviews/sec):264.3 #Correct:44 #Trained:90 Training Accuracy:48.8%Progress:0.37% Speed(reviews/sec):265.0 #Correct:45 #Trained:92 Training Accuracy:48.9%Progress:0.38% S ...
# Progress:20.8% Speed(reviews/sec):267.0 #Correct:2499 #Trained:5000 Training Accuracy:49.9%Progress:10.4% Speed(reviews/sec):271.9 #Correct:1251 #Trained:2503 Training Accuracy:49.9%Progress:10.4% Speed(reviews/sec):271.8 #Correct:1252 #Trained:2505 Training Accuracy:49.9%Progress:10.4% Speed(reviews/sec):271.8 #Correct:1253 #Trained:2507 Training Accuracy:49.9%Progress:10.4% Speed(reviews/sec):271.8 #Correct:1254 #Trained:2509 Training Accuracy:49.9%Progress:10.4% Speed(reviews/sec):271.7 #Correct:1255 #Trained:2511 Training Accuracy:49.9%Progress:10.4% Speed(reviews/sec):271.7 #Correct:1256 #Trained:2514 Training Accuracy:49.9%Progress:10.4% Speed(reviews/sec):271.7 #Correct:1257 #Trained:2516 Training Accuracy:49.9%Progress:10.4% Speed(reviews/sec):271.6 #Correct:1258 #Trained:2518 Training Accuracy:49.9%Progress:10.4% Speed(reviews/sec):271.6 #Correct:1259 #Trained:2520 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1260 #Trained:2522 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1261 #Trained:2524 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1262 #Trained:2526 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1263 #Trained:2528 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1264 #Trained:2530 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1265 #Trained:2532 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1266 #Trained:2534 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1267 #Trained:2536 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1268 #Trained:2538 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1269 #Trained:2540 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.6 #Correct:1270 #Trained:2542 Training Accuracy:49.9%Progress:10.5% Speed(reviews/sec):271.5 #Correct:1271 #Trained:2544 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.5 #Correct:1272 #Trained:2546 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.5 #Correct:1273 #Trained:2548 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.5 #Correct:1274 #Trained:2550 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.5 #Correct:1275 #Trained:2552 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.5 #Correct:1276 #Trained:2554 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.5 #Correct:1277 #Trained:2556 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.5 #Correct:1278 #Trained:2558 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.4 #Correct:1279 #Trained:2560 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.4 #Correct:1280 #Trained:2562 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.4 #Correct:1281 #Trained:2564 Training Accuracy:49.9%Progress:10.6% Speed(reviews/sec):271.4 #Correct:1283 #Trained:2567 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1284 #Trained:2569 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1285 #Trained:2571 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1286 #Trained:2573 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1287 #Trained:2575 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.3 #Correct:1288 #Trained:2577 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1289 #Trained:2579 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1290 #Trained:2581 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1291 #Trained:2583 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1292 #Trained:2585 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1293 #Trained:2587 Training Accuracy:49.9%Progress:10.7% Speed(reviews/sec):271.4 #Correct:1294 #Trained:2589 Training Accuracy:4 ...
# Progress:31.2% Speed(reviews/sec):262.2 #Correct:3749 #Trained:7500 Training Accuracy:49.9%Progress:20.8% Speed(reviews/sec):267.0 #Correct:2501 #Trained:5003 Training Accuracy:49.9%Progress:20.8% Speed(reviews/sec):267.0 #Correct:2502 #Trained:5005 Training Accuracy:49.9%Progress:20.8% Speed(reviews/sec):267.0 #Correct:2503 #Trained:5007 Training Accuracy:49.9%Progress:20.8% Speed(reviews/sec):267.0 #Correct:2504 #Trained:5009 Training Accuracy:49.9%Progress:20.8% Speed(reviews/sec):267.0 #Correct:2505 #Trained:5011 Training Accuracy:49.9%Progress:20.8% Speed(reviews/sec):267.0 #Correct:2506 #Trained:5013 Training Accuracy:49.9%Progress:20.8% Speed(reviews/sec):267.0 #Correct:2507 #Trained:5015 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2508 #Trained:5017 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2509 #Trained:5019 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2510 #Trained:5021 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2511 #Trained:5023 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2512 #Trained:5025 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2513 #Trained:5027 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2514 #Trained:5029 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2515 #Trained:5031 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2516 #Trained:5033 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2517 #Trained:5035 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2518 #Trained:5037 Training Accuracy:49.9%Progress:20.9% Speed(reviews/sec):267.0 #Correct:2519 #Trained:5039 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2520 #Trained:5041 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2521 #Trained:5043 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2522 #Trained:5045 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2523 #Trained:5047 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2524 #Trained:5049 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2525 #Trained:5051 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2526 #Trained:5053 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2527 #Trained:5055 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2528 #Trained:5057 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2529 #Trained:5059 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2530 #Trained:5061 Training Accuracy:49.9%Progress:21.0% Speed(reviews/sec):267.0 #Correct:2531 #Trained:5063 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2532 #Trained:5065 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2533 #Trained:5067 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2534 #Trained:5069 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2535 #Trained:5071 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2536 #Trained:5073 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2537 #Trained:5075 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2538 #Trained:5077 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2539 #Trained:5079 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2540 #Trained:5081 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2541 #Trained:5083 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2542 #Trained:5085 Training Accuracy:49.9%Progress:21.1% Speed(reviews/sec):267.0 #Correct:2543 #Trained:5087 Training Accuracy:4 ...
# Progress:41.6% Speed(reviews/sec):255.5 #Correct:4999 #Trained:10000 Training Accuracy:49.9%rogress:31.2% Speed(reviews/sec):262.2 #Correct:3751 #Trained:7503 Training Accuracy:49.9%Progress:31.2% Speed(reviews/sec):262.2 #Correct:3752 #Trained:7505 Training Accuracy:49.9%Progress:31.2% Speed(reviews/sec):262.2 #Correct:3753 #Trained:7507 Training Accuracy:49.9%Progress:31.2% Speed(reviews/sec):262.2 #Correct:3754 #Trained:7509 Training Accuracy:49.9%Progress:31.2% Speed(reviews/sec):262.2 #Correct:3755 #Trained:7511 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.2 #Correct:3756 #Trained:7513 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.2 #Correct:3757 #Trained:7516 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.2 #Correct:3758 #Trained:7518 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.1 #Correct:3759 #Trained:7520 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.1 #Correct:3760 #Trained:7522 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.2 #Correct:3761 #Trained:7524 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.2 #Correct:3762 #Trained:7526 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.2 #Correct:3763 #Trained:7528 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.2 #Correct:3764 #Trained:7530 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.2 #Correct:3765 #Trained:7532 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.2 #Correct:3766 #Trained:7534 Training Accuracy:49.9%Progress:31.3% Speed(reviews/sec):262.1 #Correct:3767 #Trained:7536 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.1 #Correct:3768 #Trained:7538 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.1 #Correct:3769 #Trained:7540 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.1 #Correct:3770 #Trained:7542 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.2 #Correct:3771 #Trained:7544 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.2 #Correct:3772 #Trained:7546 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.2 #Correct:3773 #Trained:7548 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.2 #Correct:3774 #Trained:7550 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.1 #Correct:3775 #Trained:7552 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.1 #Correct:3776 #Trained:7554 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.1 #Correct:3777 #Trained:7556 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.1 #Correct:3778 #Trained:7558 Training Accuracy:49.9%Progress:31.4% Speed(reviews/sec):262.1 #Correct:3779 #Trained:7560 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3780 #Trained:7562 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3781 #Trained:7564 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3782 #Trained:7566 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3784 #Trained:7569 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3785 #Trained:7571 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3786 #Trained:7573 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3787 #Trained:7575 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3788 #Trained:7577 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3789 #Trained:7579 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3790 #Trained:7581 Training Accuracy:49.9%Progress:31.5% Speed(reviews/sec):262.1 #Correct:3791 #Trained:7583 Training Accuracy:49.9%Progress:31.6% Speed(reviews/sec):262.1 #Correct:3792 #Trained:7585 Training Accuracy:49.9%Progress:31.6% Speed(reviews/sec):262.1 #Correct:3793 #Trained:7587 Training Accuracy:49.9%Progress:31.6% Speed(reviews/sec):262.1 #Correct:3794 #Trained:7589 Training Accuracy:4 ...
# Progress:52.0% Speed(reviews/sec):253.3 #Correct:6250 #Trained:12501 Training Accuracy:49.9%Progress:41.6% Speed(reviews/sec):255.5 #Correct:5001 #Trained:10003 Training Accuracy:49.9%Progress:41.6% Speed(reviews/sec):255.5 #Correct:5002 #Trained:10005 Training Accuracy:49.9%Progress:41.6% Speed(reviews/sec):255.5 #Correct:5003 #Trained:10007 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.5 #Correct:5004 #Trained:10009 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.5 #Correct:5005 #Trained:10011 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.5 #Correct:5006 #Trained:10013 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.5 #Correct:5007 #Trained:10015 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.5 #Correct:5008 #Trained:10017 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.4 #Correct:5009 #Trained:10019 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.4 #Correct:5010 #Trained:10021 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.4 #Correct:5011 #Trained:10023 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.4 #Correct:5012 #Trained:10025 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.4 #Correct:5013 #Trained:10027 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.4 #Correct:5014 #Trained:10029 Training Accuracy:49.9%Progress:41.7% Speed(reviews/sec):255.4 #Correct:5015 #Trained:10031 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5016 #Trained:10033 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5017 #Trained:10035 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5018 #Trained:10037 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5019 #Trained:10039 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5020 #Trained:10041 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5021 #Trained:10043 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5022 #Trained:10045 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5023 #Trained:10047 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5024 #Trained:10049 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5025 #Trained:10051 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5026 #Trained:10053 Training Accuracy:49.9%Progress:41.8% Speed(reviews/sec):255.4 #Correct:5027 #Trained:10055 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5028 #Trained:10057 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5029 #Trained:10059 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5030 #Trained:10061 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5031 #Trained:10063 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5032 #Trained:10065 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5033 #Trained:10067 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5034 #Trained:10069 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5035 #Trained:10071 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5036 #Trained:10073 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5037 #Trained:10075 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5038 #Trained:10077 Training Accuracy:49.9%Progress:41.9% Speed(reviews/sec):255.3 #Correct:5039 #Trained:10079 Training Accuracy:49.9%Progress:42.0% Speed(reviews/sec):255.3 #Correct:5040 #Trained:10081 Training Accuracy:49.9%Progress:42.0% Speed(reviews/sec):255.3 #Correct:5041 #Trained:10083 Training Accuracy:49.9%Progress:42.0% Speed(reviews/sec):255.3 #Correct:5042 #Trained:10085 Training Accuracy:49.9%Progress:42.0% Speed(reviews/sec):255.3 #Cor ...
# Progress:60.6% Speed(reviews/sec):253.9 #Correct:7275 #Trained:14551 Training Accuracy:49.9%Progress:52.0% Speed(reviews/sec):253.3 #Correct:6251 #Trained:12503 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6252 #Trained:12505 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6253 #Trained:12507 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6254 #Trained:12509 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6255 #Trained:12511 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6256 #Trained:12513 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6257 #Trained:12515 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6258 #Trained:12517 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6259 #Trained:12519 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6260 #Trained:12521 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6261 #Trained:12523 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6262 #Trained:12525 Training Accuracy:49.9%Progress:52.1% Speed(reviews/sec):253.3 #Correct:6263 #Trained:12527 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6264 #Trained:12529 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6265 #Trained:12531 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6266 #Trained:12533 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6267 #Trained:12535 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6268 #Trained:12537 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6269 #Trained:12539 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6270 #Trained:12541 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6271 #Trained:12543 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6272 #Trained:12545 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6273 #Trained:12547 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6274 #Trained:12550 Training Accuracy:49.9%Progress:52.2% Speed(reviews/sec):253.3 #Correct:6275 #Trained:12552 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6276 #Trained:12554 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6277 #Trained:12556 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6278 #Trained:12558 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6279 #Trained:12560 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6280 #Trained:12562 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6281 #Trained:12564 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6282 #Trained:12566 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6283 #Trained:12568 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6284 #Trained:12570 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6285 #Trained:12572 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6286 #Trained:12574 Training Accuracy:49.9%Progress:52.3% Speed(reviews/sec):253.3 #Correct:6287 #Trained:12576 Training Accuracy:49.9%Progress:52.4% Speed(reviews/sec):253.3 #Correct:6288 #Trained:12578 Training Accuracy:49.9%Progress:52.4% Speed(reviews/sec):253.3 #Correct:6289 #Trained:12580 Training Accuracy:49.9%Progress:52.4% Speed(reviews/sec):253.3 #Correct:6290 #Trained:12582 Training Accuracy:49.9%Progress:52.4% Speed(reviews/sec):253.3 #Correct:6291 #Trained:12584 Training Accuracy:49.9%Progress:52.4% Speed(reviews/sec):253.3 #Correct:6292 #Trained:12586 Training Accuracy:49.9%Progress:52.4% Speed(reviews/sec):253.3 #Cor ...

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)

# %%
# train the network
mlp.train(reviews[:-1000],labels[:-1000])

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)

# %%
# train the network
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# # Understanding Neural Noise

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()
